# %% [markdown]
# # ETS MARL — Priority 3: Tanh Saturation Fix
#
# **P1 anti-convergence + P2 structural + P3: Clipped Gaussian & ε-Greedy**
#
# This notebook is a testing playground for the ETS MARL simulation.
# It clones the repository, installs dependencies, runs tests, trains agents,
# and visualizes results — all within Google Colab.
#
# ---
#
# ### P3 Fixes (this experiment)
# - **Clipped Gaussian** replaces tanh squashing in AuctionPolicy & SecondaryPolicy
#   - `action = clamp(raw, -1, 1) * scale + bias` instead of `tanh(raw) * scale + bias`
#   - Gradient = 1.0 inside bounds (vs tanh → 0.01 at boundaries)
#   - Eliminates the absorbing state that trapped A2 at floor bid (40€)
# - **Physical-space ε-greedy**: uniform random actions with P=ε
#   - ε decays from 15% → 2% over 5000 episodes
#   - Guarantees exploration of the full [40, 120]€ bid range
#   - Raw action + log_prob computed under current policy for correct PPO ratios
#
# ### Model Overview (v5.0)
# - **8 agents** representing European electricity utilities (10 TWh/year each)
#   - 4 archetypes × 2 replicas: coal-heavy, gas-dominant, mixed, near-green
# - **5 technologies**: Coal, Gas CCGT, Onshore Wind, Offshore Wind, Solar PV
# - **Real-data-grounded** CapEx (IRENA 2024), emission factors (IPCC AR5), deployment delays
# - **EU ETS mechanics**: uniform-price auction, MSR, LRF (Fit for 55), 100% auctioning
# - **PPO agents** with two-phase decisions (auction + secondary market)
# - **Greening-only** constraint: agents can only add renewables, fossil can only decrease
# - **MAC fuel-switching**: automatic coal→gas dispatch switching at marginal cost (€65/tCO₂)
# - **Electricity revenue**: margin-based reward (output × electricity price)
# - **Carry-forward obligations**: non-compliance shortfall added to next year's surrender
# - **Soft agent cycling**: all agents learn every episode (non-active at reduced LR)

# %%
import os, sys, subprocess
from pathlib import Path

REPO_URL = "https://github.com/DJH961/Thesis-Energy-Auction.git"
BRANCH = "Version_ten"
PROJECT_SUBDIR = "ets_marl ppo copia 2"

def _is_project_root(path: Path) -> bool:
    return (path / "src").is_dir() and (path / "configs").is_dir()

# Se hai indicato una repo, usa quella come fonte di verità
if REPO_URL:
    os.chdir("/content")

    repo_name = Path(REPO_URL.rstrip("/")).name.replace(".git", "")
    clone_dir = Path("/content") / repo_name

    if clone_dir.exists():
        print(f"Removing existing clone: {clone_dir}")
        subprocess.run(["rm", "-rf", str(clone_dir)], check=False)

    clone_cmd = ["git", "clone", "-b", BRANCH, REPO_URL, str(clone_dir)]
    print("Cloning:", " ".join(clone_cmd))
    subprocess.run(clone_cmd, check=True)

    # 1) prova esplicitamente la sottocartella richiesta
    if PROJECT_SUBDIR:
        target = clone_dir / PROJECT_SUBDIR
        if not _is_project_root(target):
            raise FileNotFoundError(
                f"PROJECT_SUBDIR non valido: {target}\n"
                f"Contenuto repo: {os.listdir(clone_dir)}"
            )
        os.chdir(target)
    else:
        # 2) altrimenti prova root repo, poi una cartella sotto
        candidates = [clone_dir] + [p for p in clone_dir.iterdir() if p.is_dir()]
        found = None
        for cand in candidates:
            if _is_project_root(cand):
                found = cand
                break
        if found is None:
            raise FileNotFoundError(
                f"Non trovo src/ e configs/ dentro {clone_dir}\n"
                f"Contenuto repo: {os.listdir(clone_dir)}"
            )
        os.chdir(found)

else:
    # fallback locale
    local_candidates = [Path("."), Path(".."), Path("../..")]
    found = None
    for cand in local_candidates:
        if _is_project_root(cand):
            found = cand
            break
    if found is None:
        raise FileNotFoundError(
            "Cannot find project root locally. Set REPO_URL in this cell."
        )
    os.chdir(found)

sys.path.insert(0, os.getcwd())
print("Working directory:", os.getcwd())
# !git branch --show-current
# !git log -1 --oneline
print("Files here:", os.listdir("."))
# Out:
# Cloning: git clone -b Version_ten https://github.com/DJH961/Thesis-Energy-Auction.git /content/Thesis-Energy-Auction
# Working directory: /content/Thesis-Energy-Auction/ets_marl ppo copia 2
# Version_ten
# 77f8348 (HEAD -> Version_ten, origin/Version_ten) Add files via upload
# Files here: ['docs', 'README.md', 'install.bat', 'results', 'pyproject.toml', 'uv.lock', 'notebooks', 'tests', 'requirements.txt', 'setup.sh', 'configs', 'scripts', 'src', 'main.py']

# %% [markdown]
# ## 1. Setup — Clone Repository & Install Dependencies

# %%
# Install dependencies
if os.path.exists("requirements.txt"):
    # !pip install -q -r requirements.txt
else:
    # !pip install -q gymnasium numpy torch pyyaml pandas matplotlib seaborn pytest numpy-groupies

# Verify GPU availability
import torch
print(f'PyTorch version: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 2.0 MB/s eta 0:00:00
# PyTorch version: 2.10.0+cpu
# CUDA available: False

# %%
# ── P3 Code Patches: Clipped Gaussian + Epsilon-Greedy ──
# These modify source files to replace tanh squashing with clamp
# and add physical-space epsilon-greedy exploration.

import re

# --- 1. Patch actor_critic.py: tanh → clamp ---
ac_path = 'src/agents/actor_critic.py'
with open(ac_path) as f:
    ac_code = f.read()

# Replace tanh squashing with clamp in act() methods (both policies)
ac_code = ac_code.replace(
    'squashed = torch.tanh(raw)',
    'squashed = torch.clamp(raw, -1.0, 1.0)'
)
# Remove tanh log-prob correction in act() methods
ac_code = ac_code.replace(
    'log_prob = dist.log_prob(raw) - torch.log(1 - squashed.pow(2) + 1e-6)\n'
    '        log_prob = log_prob.sum(dim=-1, keepdim=True)',
    'log_prob = dist.log_prob(raw).sum(dim=-1, keepdim=True)'
)
# Remove tanh correction in evaluate() methods
ac_code = ac_code.replace(
    'log_prob = dist.log_prob(raw_actions)\n'
    '        squashed = torch.tanh(raw_actions)\n'
    '        log_prob = log_prob - torch.log(1 - squashed.pow(2) + 1e-6)\n'
    '        log_prob = log_prob.sum(dim=-1, keepdim=True)',
    'log_prob = dist.log_prob(raw_actions).sum(dim=-1, keepdim=True)'
)

with open(ac_path, 'w') as f:
    f.write(ac_code)
print(f'✅ Patched {ac_path}: tanh → clamp, removed log-prob correction')

# --- 2. Patch train.py: _to_pretanh → _to_raw ---
train_path = 'scripts/train.py'
with open(train_path) as f:
    train_code = f.read()

# Rename function and remove atanh
train_code = train_code.replace('_to_pretanh', '_to_raw')
train_code = train_code.replace(
    'normalized = torch.clamp((h_t - bias) / (scale + 1e-8), -1.0 + 1e-6, 1.0 - 1e-6)\n'
    '    return torch.atanh(normalized).cpu().numpy()',
    'return torch.clamp((h_t - bias) / (scale + 1e-8), -1.0, 1.0).cpu().numpy()'
)

with open(train_path, 'w') as f:
    f.write(train_code)
print(f'✅ Patched {train_path}: _to_pretanh → _to_raw (no atanh)')

# --- 3. Patch ppo_agent.py: add epsilon-greedy ---
ppo_path = 'src/agents/ppo_agent.py'
with open(ppo_path) as f:
    ppo_code = f.read()

# Add epsilon to select_auction_action
ppo_code = ppo_code.replace(
    'def select_auction_action(self, obs1: np.ndarray, deterministic=False):',
    'def select_auction_action(self, obs1: np.ndarray, deterministic=False,\n'
    '                              epsilon: float = 0.0):'
)
# Inject epsilon logic after the normal action selection
old_return_auc = (
    '        return (action.cpu().numpy().squeeze(0),\n'
    '                raw.cpu().numpy().squeeze(0),\n'
    '                log_prob.cpu().numpy().squeeze(0))\n'
    '\n'
    '    def select_secondary_action'
)
new_return_auc = (
    '        if not deterministic and epsilon > 0.0 and np.random.random() < epsilon:\n'
    '            with torch.no_grad():\n'
    '                low = self.auction_policy.action_bias - self.auction_policy.action_scale\n'
    '                high = self.auction_policy.action_bias + self.auction_policy.action_scale\n'
    '                rand_action = torch.rand_like(action) * (high - low) + low\n'
    '                rand_raw = torch.clamp(\n'
    '                    (rand_action - self.auction_policy.action_bias) /\n'
    '                    (self.auction_policy.action_scale + 1e-8), -1.0, 1.0)\n'
    '                dist = self.auction_policy.forward(obs_t)\n'
    '                rand_lp = dist.log_prob(rand_raw).sum(dim=-1, keepdim=True)\n'
    '            return (rand_action.cpu().numpy().squeeze(0),\n'
    '                    rand_raw.cpu().numpy().squeeze(0),\n'
    '                    rand_lp.cpu().numpy().squeeze(0))\n'
    '\n'
    '        return (action.cpu().numpy().squeeze(0),\n'
    '                raw.cpu().numpy().squeeze(0),\n'
    '                log_prob.cpu().numpy().squeeze(0))\n'
    '\n'
    '    def select_secondary_action'
)
ppo_code = ppo_code.replace(old_return_auc, new_return_auc)

# Add epsilon to select_secondary_action
ppo_code = ppo_code.replace(
    'def select_secondary_action(self, obs2: np.ndarray, deterministic=False):',
    'def select_secondary_action(self, obs2: np.ndarray, deterministic=False,\n'
    '                                epsilon: float = 0.0):'
)
old_return_sec = (
    '        return (action.cpu().numpy().squeeze(0),\n'
    '                raw.cpu().numpy().squeeze(0),\n'
    '                log_prob.cpu().numpy().squeeze(0))\n'
    '\n'
    '    def estimate_value'
)
new_return_sec = (
    '        if not deterministic and epsilon > 0.0 and np.random.random() < epsilon:\n'
    '            with torch.no_grad():\n'
    '                low = self.secondary_policy.action_bias - self.secondary_policy.action_scale\n'
    '                high = self.secondary_policy.action_bias + self.secondary_policy.action_scale\n'
    '                rand_action = torch.rand_like(action) * (high - low) + low\n'
    '                rand_raw = torch.clamp(\n'
    '                    (rand_action - self.secondary_policy.action_bias) /\n'
    '                    (self.secondary_policy.action_scale + 1e-8), -1.0, 1.0)\n'
    '                dist = self.secondary_policy.forward(obs_t)\n'
    '                rand_lp = dist.log_prob(rand_raw).sum(dim=-1, keepdim=True)\n'
    '            return (rand_action.cpu().numpy().squeeze(0),\n'
    '                    rand_raw.cpu().numpy().squeeze(0),\n'
    '                    rand_lp.cpu().numpy().squeeze(0))\n'
    '\n'
    '        return (action.cpu().numpy().squeeze(0),\n'
    '                raw.cpu().numpy().squeeze(0),\n'
    '                log_prob.cpu().numpy().squeeze(0))\n'
    '\n'
    '    def estimate_value'
)
ppo_code = ppo_code.replace(old_return_sec, new_return_sec)

with open(ppo_path, 'w') as f:
    f.write(ppo_code)
print(f'✅ Patched {ppo_path}: added epsilon-greedy to select_*_action()')

# --- 4. Patch train.py: add epsilon schedule + pass-through ---
with open(train_path) as f:
    train_code = f.read()

# Add epsilon schedule after entropy tracker init
train_code = train_code.replace(
    '# Condition-based entropy tracker',
    '# Epsilon-greedy exploration schedule\n'
    '    explore_cfg = config.get("exploration", {})\n'
    '    eps_start = explore_cfg.get("epsilon_start", 0.0)\n'
    '    eps_final = explore_cfg.get("epsilon_final", 0.0)\n'
    '    eps_decay_episodes = explore_cfg.get("epsilon_decay_episodes", 5000)\n'
    '    if eps_start > 0.0:\n'
    '        print(f"Epsilon-greedy: {eps_start:.2f} \\u2192 {eps_final:.2f} "\n'
    '              f"over {eps_decay_episodes} episodes (physical-space).")\n'
    '\n'
    '    # Condition-based entropy tracker'
)

# Add epsilon computation in episode loop (after set_episode)
train_code = train_code.replace(
    'obs1, _ = env.reset(seed=seed + episode * 1000)',
    '# Epsilon-greedy schedule\n'
    '        if eps_start > 0.0:\n'
    '            eps_frac = min(1.0, episode / max(eps_decay_episodes, 1))\n'
    '            current_epsilon = eps_start + eps_frac * (eps_final - eps_start)\n'
    '        else:\n'
    '            current_epsilon = 0.0\n'
    '\n'
    '        obs1, _ = env.reset(seed=seed + episode * 1000)'
)

# Pass epsilon to action selection calls
train_code = train_code.replace(
    'agents[i].select_auction_action(obs1[i])',
    'agents[i].select_auction_action(obs1[i], epsilon=current_epsilon)'
)
train_code = train_code.replace(
    'agents[i].select_secondary_action(obs2[i])',
    'agents[i].select_secondary_action(obs2[i], epsilon=current_epsilon)'
)

with open(train_path, 'w') as f:
    f.write(train_code)
print(f'✅ Patched {train_path}: epsilon schedule + pass-through')

print('\n✅ All P3 code patches applied successfully.')
# Out:
# ✅ Patched src/agents/actor_critic.py: tanh → clamp, removed log-prob correction
# ✅ Patched scripts/train.py: _to_pretanh → _to_raw (no atanh)
# ✅ Patched src/agents/ppo_agent.py: added epsilon-greedy to select_*_action()
# ✅ Patched scripts/train.py: epsilon schedule + pass-through
#
# ✅ All P3 code patches applied successfully.

# %% [markdown]
# ## 2. Run Tests — Verify Everything Works

# %%
# !python -m pytest tests/ -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/Thesis-Energy-Auction/ets_marl ppo copia 2
# configfile: pyproject.toml
# plugins: anyio-4.12.1, langsmith-0.7.16, typeguard-4.5.1
# collected 66 items
#
# tests/test_cap_schedule.py::test_cap_year_0 PASSED                       [  1%]
# tests/test_cap_schedule.py::test_cap_year_1_lrf_phase1 PASSED            [  3%]
# tests/test_cap_schedule.py::test_cap_year_5_switches_to_phase2 PASSED    [  4%]
# tests/test_cap_schedule.py::test_cap_strictly_decreasing PASSED          [  6%]
# tests/test_cap_schedule.py::test_cap_year_10 PASSED                      [  7%]
# tests/test_cap_schedule.py::test_msr_no_adjustment_within_band PASSED    [  9%]
# tests/test_cap_schedule.py::test_msr_withhold_when_tnac_high PASSED      [ 10%]
# tests/test_cap_schedule.py::test_msr_release_when_tnac_low PASSED        [ 12%]
# tests/test_cap_schedule.py::test_msr_disabled PASSED                     [ 13%]
# tests/test_cap_schedule.py::test_msr_volume_never_negative PASSED        [ 15%]
# tests/test_cap_schedule.py::test_msr_reset PASSED                        [ 16%]
# tests/test_clipped_gaussian.py::test_act_output_bounds PASSED            [ 18%]
# tests/test_clipped_gaussian.py::test_evaluate_log_prob_consistency PASSED [ 19%]
# tests/test_clipped_gaussian.py::test_clamp_gradient_flow PASSED          [ 21%]
# tests/test_clipped_gaussian.py::test_to_raw_invertibility PASSED         [ 22%]
# tests/test_clipped_gaussian.py::test_epsilon_greedy_auction PASSED       [ 24%]
# tests/test_clipped_gaussian.py::test_epsilon_greedy_deterministic_bypass PASSED [ 25%]
# tests/test_clipped_gaussian.py::test_epsilon_zero_is_noop PASSED         [ 27%]
# tests/test_clipped_gaussian.py::test_ppo_update_with_epsilon_actions PASSED [ 28%]
# tests/test_environment.py::test_reset_obs_shape PASSED                   [ 30%]
# tests/test_environment.py::test_two_phase_step_runs PASSED               [ 31%]
# tests/test_environment.py::test_episode_length PASSED                    [ 33%]
# tests/test_environment.py::test_cap_decreases PASSED                     [ 34%]
# tests/test_environment.py::test_rewards_finite PASSED                    [ 36%]
# tests/test_environment.py::test_tech_mix_sums_to_one PASSED              [ 37%]
# tests/test_environment.py::test_green_fraction_non_decreasing PASSED     [ 39%]
# tests/test_environment.py::test_reproducibility PASSED                   [ 40%]
# tests/test_environment.py::test_different_seeds_differ PASSED            [ 42%]
# tests/test_environment.py::test_year_log_keys PASSED                     [ 43%]
# tests/test_environment.py::test_emissions_decrease_with_green PASSED     [ 45%]
# tests/test_environment.py::test_investment_costs_realistic PASSED        [ 46%]
# tests/test_environment.py::test_p5_emission_variance PASSED              [ 48%]
# tests/test_environment.py::test_p6_cf_noise_stability PASSED             [ 50%]
# tests/test_environment.py::test_p7_warm_start_bank PASSED                [ 51%]
# tests/test_environment.py::test_p7_price_history_seeded PASSED           [ 53%]
# tests/test_environment.py::test_p8_obs_dims PASSED                       [ 54%]
# tests/test_mappo.py::test_centralized_critic_dimensions PASSED           [ 56%]
# tests/test_mappo.py::test_ippo_critic_dimensions PASSED                  [ 57%]
# tests/test_mappo.py::test_rollout_buffer_global_state PASSED             [ 59%]
# tests/test_mappo.py::test_rollout_buffer_no_global_state PASSED          [ 60%]
# tests/test_mappo.py::test_build_agents_mappo PASSED                      [ 62%]
# tests/test_mappo.py::test_build_agents_ippo_fallback PASSED              [ 63%]
# tests/test_mappo.py::test_estimate_value_global_state PASSED             [ 65%]
# tests/test_mappo.py::test_mappo_full_episode PASSED                      [ 66%]
# tests/test_market_clearing.py::test_clearing_price_basic PASSED          [ 68%]
# tests/test_market_clearing.py::test_quantity_conservation PASSED         [ 69%]
# tests/test_market_clearing.py::test_uniform_price_payment PASSED         [ 71%]
# tests/test_market_clearing.py::test_reserve_price PASSED                 [ 72%]
# tests/test_market_clearing.py::test_all_below_reserve PASSED             [ 74%]
# tests/test_market_clearing.py::test_single_bidder PASSED                 [ 75%]
# tests/test_market_clearing.py::test_large_bid PASSED                     [ 77%]
# tests/test_market_clearing.py::test_tie_break_random PASSED              [ 78%]
# tests/test_market_clearing.py::test_tie_break_reproducible PASSED        [ 80%]
# tests/test_market_clearing.py::test_tie_break_partial_fill PASSED        [ 81%]
# tests/test_market_clearing.py::test_non_negativity PASSED                [ 83%]
# tests/test_market_clearing.py::test_build_bids PASSED                    [ 84%]
# tests/test_market_clearing.py::test_holding_limit PASSED                 [ 86%]
# tests/test_market_clearing.py::test_holding_limit_no_effect_when_1 PASSED [ 87%]
# tests/test_market_clearing.py::test_holding_limit_redistributes PASSED   [ 89%]
# tests/test_market_clearing.py::test_under_subscription_cancels_when_enabled PASSED [ 90%]
# tests/test_market_clearing.py::test_under_subscription_proceeds_by_default PASSED [ 92%]
# tests/test_market_clearing.py::test_exact_subscription_succeeds PASSED   [ 93%]
# tests/test_market_clearing.py::test_empty_bids PASSED                    [ 95%]
# tests/test_market_clearing.py::test_unsold_in_stats PASSED               [ 96%]
# tests/test_market_clearing.py::test_user_worked_example PASSED           [ 98%]
# tests/test_market_clearing.py::test_stats_fail_reason PASSED             [100%]
#
# ============================= 66 passed in 20.72s ==============================

# %% [markdown]
# ## 3. Explore the Environment

# %%
import os, yaml
print("CWD:", os.getcwd())

with open("configs/default.yaml") as f:
    config = yaml.safe_load(f)

print("Config keys:", list(config.keys()))
# Out:
# CWD: /content/Thesis-Energy-Auction/ets_marl ppo copia 2
# Config keys: ['simulation', 'technologies', 'ets', 'companies', 'investment', 'risk', 'auction', 'trading', 'budget', 'penalty', 'price', 'mac', 'electricity', 'reward', 'opponent_modeling', 'agent_cycling', 'ppo', 'curriculum', 'uncertainty', 'construction_jitter', 'warm_start', 'logging', 'pretrain', 'diagnostics', 'exploration']

# %%
import sys
sys.path.insert(0, '.')

import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.environment.ets_environment import ETSEnvironment

with open('configs/default.yaml') as f:
    config = yaml.safe_load(f)

env = ETSEnvironment(config, seed=42)
obs1, _ = env.reset()

tech_names = config['technologies']['names']

print('=== Environment Summary ===')
print(f'Agents: {env.n_agents}')
print(f'Years: {env.n_years}')
print(f'Technologies: {tech_names}')
print(f'Phase 1 obs dim: {obs1.shape[1]}')
print(f'Initial cap: {env.cap_schedule.get_cap(0):.2f} Mt')
print()

for i, c in enumerate(env.companies):
    mix_str = ' | '.join([f'{tech_names[t]}: {c.mix[t]*100:.0f}%' for t in range(len(tech_names))])
    print(f'A{i+1}: {mix_str}')
    print(f'     Emissions: {c.compute_emissions():.2f} Mt | '
          f'Green: {c.green_frac*100:.0f}% | '
          f'Op. Cost: {c.compute_operational_cost():.0f} M€/yr | '
          f'Avg EF: {c.weighted_emission_factor:.3f} tCO2/MWh')
# Out:
# === Environment Summary ===
# Agents: 8
# Years: 12
# Technologies: ['coal', 'gas', 'onshore_wind', 'offshore_wind', 'solar']
# Phase 1 obs dim: 35
# Initial cap: 23.50 Mt
#
# A1: coal: 40% | gas: 40% | onshore_wind: 10% | offshore_wind: 5% | solar: 5%
#      Emissions: 5.28 Mt | Green: 20% | Op. Cost: 554 M€/yr | Avg EF: 0.528 tCO2/MWh
# A2: coal: 40% | gas: 40% | onshore_wind: 10% | offshore_wind: 5% | solar: 5%
#      Emissions: 5.28 Mt | Green: 20% | Op. Cost: 554 M€/yr | Avg EF: 0.528 tCO2/MWh
# A3: coal: 15% | gas: 45% | onshore_wind: 20% | offshore_wind: 10% | solar: 10%
#      Emissions: 3.52 Mt | Green: 40% | Op. Cost: 446 M€/yr | Avg EF: 0.352 tCO2/MWh
# A4: coal: 15% | gas: 45% | onshore_wind: 20% | offshore_wind: 10% | solar: 10%
#      Emissions: 3.52 Mt | Green: 40% | Op. Cost: 446 M€/yr | Avg EF: 0.352 tCO2/MWh
# A5: coal: 5% | gas: 25% | onshore_wind: 35% | offshore_wind: 20% | solar: 15%
#      Emissions: 1.77 Mt | Green: 70% | Op. Cost: 342 M€/yr | Avg EF: 0.177 tCO2/MWh
# A6: coal: 5% | gas: 25% | onshore_wind: 35% | offshore_wind: 20% | solar: 15%
#      Emissions: 1.77 Mt | Green: 70% | Op. Cost: 342 M€/yr | Avg EF: 0.177 tCO2/MWh
# A7: coal: 0% | gas: 10% | onshore_wind: 30% | offshore_wind: 35% | solar: 25%
#      Emissions: 0.69 Mt | Green: 90% | Op. Cost: 296 M€/yr | Avg EF: 0.069 tCO2/MWh
# A8: coal: 0% | gas: 10% | onshore_wind: 30% | offshore_wind: 35% | solar: 25%
#      Emissions: 0.69 Mt | Green: 90% | Op. Cost: 296 M€/yr | Avg EF: 0.069 tCO2/MWh

# %% [markdown]
# ## 4. Run a Random-Policy Episode (Baseline)

# %%
env = ETSEnvironment(config, seed=42)
obs1, _ = env.reset(seed=42)
n_agents = env.n_agents
rng = np.random.default_rng(42)

aq = config['auction']
inv = config['investment']
trading_cfg = config.get('trading', {})
qty_mult_low = aq.get('qty_mult_low', 0.3)
qty_mult_high = aq.get('qty_mult_high', 1.3)
sec_mult_low = trading_cfg.get('sec_mult_low', 0.8)
sec_mult_high = trading_cfg.get('sec_mult_high', 1.3)

year_data = []

for year in range(config['simulation']['n_years']):
    # Random auction actions (use config bounds)
    auction_actions = rng.uniform(
        [aq['price_min'], qty_mult_low, 0.0, -1.0, -1.0, -1.0],
        [aq['price_max'], qty_mult_high, inv['max_invest_frac'], 1.0, 1.0, 1.0],
        size=(n_agents, 6)
    ).astype(np.float32)

    obs2, _ = env.step_auction(auction_actions)

    # Random secondary actions (config-driven bounds)
    secondary_actions = rng.uniform(
        [sec_mult_low, -aq['quantity_max']], [sec_mult_high, aq['quantity_max']], size=(n_agents, 2)
    ).astype(np.float32)

    obs1, rewards, terminated, _, info = env.step_secondary(secondary_actions)
    log = info['year_log']

    row = {'year': year, 'cap': log['cap'], 'price': log['clearing_price']}
    for i in range(n_agents):
        row[f'green_A{i+1}'] = log['green_fracs'][i]
        row[f'emissions_A{i+1}'] = log['emissions'][i]
    year_data.append(row)

    if terminated:
        break

df = pd.DataFrame(year_data)
df
# Out:
#     year        cap       price  green_A1  emissions_A1  green_A2  \
# 0      0  23.500000   62.752327  0.248731      4.904799  0.231070
# 1      1  22.489500   73.643890  0.248731      4.244799  0.231070
# 2      2  21.522451  104.533447  0.348348      3.465540  0.331076
# 3      3  20.596986  120.000000  0.368571      3.301938  0.345410
# 4      4  19.690719  120.000000  0.368571      3.301938  0.345410
# 5      5  18.824327  120.000000  0.375227      3.250554  0.345410
# 6      6  17.996057  120.000000  0.375227      3.250554  0.345410
# 7      7  17.204230  120.000000  0.375227      3.250554  0.345410
# 8      8  16.447244  120.000000  0.375227      3.250554  0.345410
# 9      9  15.723565  120.000000  0.447003      2.824995  0.345410
# 10    10  15.031728  120.000000  0.484074      2.647752  0.408702
# 11    11  14.370332  120.000000  0.488970      2.626110  0.476431
#
#     emissions_A2  green_A3  emissions_A3  green_A4  emissions_A4  green_A5  \
# 0       5.029766  0.422741      3.336353  0.439737      3.195688  0.700000
# 1       4.369766  0.441391      2.833966  0.469776      2.693015  0.762998
# 2       3.592383  0.441391      2.833966  0.488144      2.605032  0.769799
# 3       3.476418  0.441391      2.833966  0.532035      2.411033  0.775965
# 4       3.476418  0.518740      2.463684  0.532035      2.411033  0.811874
# 5       3.476418  0.662403      1.778028  0.607844      2.048667  0.822732
# 6       3.476418  0.688796      1.656496  0.607844      2.048667  0.822732
# 7       3.476418  0.688796      1.656496  0.607844      2.048667  0.889300
# 8       3.476418  0.688796      1.656496  0.621585      1.982849  0.917108
# 9       3.476418  0.688796      1.656496  0.753087      1.353269  0.940782
# 10      2.993737  0.781542      1.246558  0.767931      1.282167  0.940782
# 11      2.694376  0.781542      1.246558  0.767931      1.282167  0.940782
#
#     emissions_A5  green_A6  emissions_A6  green_A7  emissions_A7  green_A8  \
# 0       1.769500  0.700000      1.769500  0.923777      0.579908  0.914507
# 1       1.322025  0.700000      1.604500  0.946467      0.479614  0.923042
# 2       1.291965  0.713923      1.542960  0.960455      0.417790  0.936358
# 3       1.262430  0.713923      1.542960  1.000000      0.241392  1.000000
# 4       1.090631  0.713923      1.542960  1.000000      0.241392  1.000000
# 5       1.038624  0.724697      1.491352  1.000000      0.241392  1.000000
# 6       1.038624  0.753342      1.354144  1.000000      0.241392  1.000000
# 7       0.744391  0.753342      1.354144  1.000000      0.241392  1.000000
# 8       0.621482  0.809837      1.083533  1.000000      0.241392  1.000000
# 9       0.508318  0.809837      1.083533  1.000000      0.241392  1.000000
# 10      0.508318  0.883078      0.759806  1.000000      0.241392  1.000000
# 11      0.508318  0.883078      0.759806  1.000000      0.241392  1.000000
#
#     emissions_A8
# 0       0.620881
# 1       0.579996
# 2       0.521139
# 3       0.214253
# 4       0.212001
# 5       0.209455
# 6       0.209455
# 7       0.209455
# 8       0.209455
# 9       0.209455
# 10      0.209455
# 11      0.209455

# %%
# Plot: Green fraction evolution (random policy)
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

# Green fracs
ax = axes[0]
for i in range(n_agents):
    ax.plot(df['year'], df[f'green_A{i+1}'] * 100, label=f'A{i+1}', marker='o', markersize=4)
ax.set_xlabel('Year')
ax.set_ylabel('Green Fraction (%)')
ax.set_title('Green Fraction (Random Policy)')
ax.legend()
ax.grid(True, alpha=0.3)

# Emissions
ax = axes[1]
for i in range(n_agents):
    ax.plot(df['year'], df[f'emissions_A{i+1}'], label=f'A{i+1}', marker='o', markersize=4)
ax.set_xlabel('Year')
ax.set_ylabel('Emissions (Mt CO₂)')
ax.set_title('Emissions (Random Policy)')
ax.legend()
ax.grid(True, alpha=0.3)

# Cap & Price
ax = axes[2]
ax.plot(df['year'], df['cap'], label='Cap (Mt)', marker='s', color='red')
ax2 = ax.twinx()
ax2.plot(df['year'], df['price'], label='Price (€/t)', marker='^', color='blue')
ax.set_xlabel('Year')
ax.set_ylabel('Cap (Mt)', color='red')
ax2.set_ylabel('Price (€/t)', color='blue')
ax.set_title('Cap Trajectory & Carbon Price')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Train PPO Agents (Short Run)

# %%
import copy
from scripts.train import train_one_seed

train_config = copy.deepcopy(config)

# Solo override logistici del run corto
train_config['simulation']['n_episodes'] = 1500
train_config['logging']['log_interval'] = 49
train_config['logging']['save_interval'] = 100

# IPPO
train_config['ppo']['centralized_critic'] = False

print("Quick run config check")
print("entropy_coef       :", train_config['ppo']['entropy_coef'])
print("entropy_coef_final :", train_config['ppo']['entropy_coef_final'])
print("epsilon_start      :", train_config['exploration']['epsilon_start'])
print("epsilon_final      :", train_config['exploration']['epsilon_final'])
print("epsilon_decay_eps  :", train_config['exploration']['epsilon_decay_episodes'])
print("stuck_boost_window :", train_config['diagnostics']['stuck_boost_window'])
print("stuck_boost_coef   :", train_config['diagnostics']['stuck_boost_coef'])
print("price_markup_low   :", train_config['auction']['price_markup_low'])
print("price_markup_high  :", train_config['auction']['price_markup_high'])

train_one_seed(train_config, seed=42)
# Out:
# Quick run config check
# entropy_coef       : 0.03
# entropy_coef_final : 0.02
# epsilon_start      : 0.25
# epsilon_final      : 0.05
# epsilon_decay_eps  : 7000
# stuck_boost_window : 250
# stuck_boost_coef   : 0.04
# price_markup_low   : 0.9
# price_markup_high  : 1.25
#
# ============================================================
# Training — seed 42, 8 agents, IPPO (independent critic), two-phase
# v5.0: MAC switching | Electricity revenue | Carry-forward | CF-cap=0.5×
# Clipped Gaussian (no tanh) + P1-P8 active | Curriculum 4→12yr | ε-greedy 25%→5%
# ============================================================
#
# ──────────────────────────────────────────────────────────────────────────────────
# TRAINING CONSOLE — COLUMN GUIDE
# ──────────────────────────────────────────────────────────────────────────────────
# Market header  (printed every log_interval episodes)
#   price X→Y (peak Z) : ETS clearing price yr-0 → yr-N and peak  (€/t)
#   cap                : Cap (Mt) in the final year
#   TNAC               : Total allowances in circulation, final year
#   sec_price/vol/match: Secondary market stats
#   entropy/shaping    : PPO entropy coef & green-shaping weight
#   [ENT-DECAY]        : Entropy decay triggered
#   [cyc=Ax]           : Active agent (soft cycling)
#
# Per-agent columns
#   Green(0→N)  : Green fraction trajectory
#   ΔGreen      : Net green change (pp)
#   AvgEmiss    : Mean emissions (Mt)
#   AvgAlloc    : Mean allocation (Mt)
#   SfYrs       : Shortfall years
#   AvgBid€     : Mean bid price (€/t)
#   BidMt       : Mean bid volume (Mt) — after coverage-multiplier expansion
#   InvFr       : Mean invest_frac action (how aggressively agent invests)
#   TotRew      : Total raw reward
#   TotShort    : Total shortfall (Mt)
#   TotPenalty  : Total penalty (M€)
#   ActLoss     : Actor loss
#   CriLoss     : Critic loss
#   MAC_Mt      : MAC fuel-switching reduction (Mt)
#   SecMl       : Mean secondary price multiplier (action[0]; 0.5=discount 2.0=premium)
#   SqAct       : Mean secondary qty action (+buy intent / -sell intent, Mt)
# ──────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────
# Behavioral cloning pre-training
#   Episodes: 300  |  Epochs: 10  |  LR: 0.001
#   Policies: AuctionPolicy + SecondaryPolicy
# ────────────────────────────────────────────────────────────
#   A1 [auction]    epoch  1/10  loss=0.3151
#   A1 [auction]    epoch 10/10  loss=0.0313
#   A1 [secondary]  epoch  1/10  loss=0.0980
#   A1 [secondary]  epoch 10/10  loss=0.0188
#   A2 [auction]    epoch  1/10  loss=0.2941
#   A2 [auction]    epoch 10/10  loss=0.0454
#   A2 [secondary]  epoch  1/10  loss=0.1007
#   A2 [secondary]  epoch 10/10  loss=0.0192
#   A3 [auction]    epoch  1/10  loss=0.2819
#   A3 [auction]    epoch 10/10  loss=0.0361
#   A3 [secondary]  epoch  1/10  loss=0.0607
#   A3 [secondary]  epoch 10/10  loss=0.0030
#   A4 [auction]    epoch  1/10  loss=0.2701
#   A4 [auction]    epoch 10/10  loss=0.0385
#   A4 [secondary]  epoch  1/10  loss=0.0671
#   A4 [secondary]  epoch 10/10  loss=0.0023
#   A5 [auction]    epoch  1/10  loss=0.2999
#   A5 [auction]    epoch 10/10  loss=0.0354
#   A5 [secondary]  epoch  1/10  loss=0.0433
#   A5 [secondary]  epoch 10/10  loss=0.0045
#   A6 [auction]    epoch  1/10  loss=0.2923
#   A6 [auction]    epoch 10/10  loss=0.0409
#   A6 [secondary]  epoch  1/10  loss=0.0366
#   A6 [secondary]  epoch 10/10  loss=0.0035
#   A7 [auction]    epoch  1/10  loss=0.2798
#   A7 [auction]    epoch 10/10  loss=0.0262
#   A7 [secondary]  epoch  1/10  loss=0.0353
#   A7 [secondary]  epoch 10/10  loss=0.0084
#   A8 [auction]    epoch  1/10  loss=0.2802
#   A8 [auction]    epoch 10/10  loss=0.0348
#   A8 [secondary]  epoch  1/10  loss=0.0375
#   A8 [secondary]  epoch 10/10  loss=0.0080
# ────────────────────────────────────────────────────────────
# Behavioral cloning pre-training complete.
#
# KL anchor: frozen BC policies captured for all 8 agents (β₀=0.5, decay=5000 eps).
# Critic-warmup: actor gradients frozen for first 100 episodes.
# Curriculum: 4yr → 12yr over 3000 episodes.
# Epsilon-greedy: 0.25 → 0.05 over 7000 episodes (physical-space).
# Epsilon-greedy: 0.25 → 0.05 over 7000 episodes (physical-space).
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep     0 │ price 46→55 (peak 55)  cap=   21  TNAC=   19 │ sec= 63.1€ vol=  9.3 match=100% │ ent=0.0300  shp=1.000  eps=0.250 [ENT-DECAY] [cyc=A1] [WARMUP 1/100]  │ warn: cov<1=1 bclust=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1*:    25→31%   +6.4   4.69   4.40   0/4     56   7.36 0.027 │    -9.4   0.00       0  0.0000  3.3734 │   0.000 │  1.12  -0.03
#   A2 :    23→29%   +5.8   4.83   3.18   1/4     52   4.89 0.033 │    -1.6   1.17     117  0.0000  1.7228 │   0.000 │  0.97  -1.10
#   A3 :    42→51%   +8.3   3.10   3.31   0/4     56   3.31 0.048 │    -7.4   0.00       0  0.0000  6.1439 │   0.000 │  1.10  -0.01
#   A4 :    44→61%  +16.6   2.71   3.94   0/4     51   3.94 0.073 │    -8.5   0.00       0  0.0000  1.6295 │   0.000 │  1.03  -0.57
#   A5 :    70→82%  +12.4   1.25   0.97   0/4     52   0.97 0.057 │    -8.0   0.00       0  0.0000  4.2434 │   0.000 │  1.20   1.16
#   A6 :    70→72%   +1.9   1.71   1.85   0/4     59   1.85 0.035 │    -9.0   0.00       0  0.0000  4.9085 │   0.000 │  1.29   0.25
#   A7 :   92→100%   +7.6   0.47   0.53   1/4     54   0.53 0.058 │    -1.3   0.09       9  0.0000  4.1103 │   0.000 │  1.11   0.09
#   A8 :    91→94%   +2.2   0.56   0.57   0/4     60   0.57 0.032 │    -8.8   0.00       0  0.0000  7.0425 │   0.000 │  1.16   1.02
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep    49 │ price 70→75 (peak 84)  cap=   21  TNAC=   29 │ sec= 82.8€ vol= 11.3 match=100% │ ent=0.0300  shp=1.000  eps=0.249 [ENT-DECAY] [cyc=A2] [WARMUP 50/100]  │ warn: cov<1=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→25%   +4.9   4.42   3.86   0/4     77   6.25 0.033 │   -10.0   0.00       0  0.0000  3.8676 │   2.640 │  1.09  -0.66
#   A2*:    21→28%   +7.6   4.20   3.36   0/4     92   3.58 0.021 │    -7.9   0.00       0  0.0000  0.1853 │   2.640 │  0.98  -0.73
#   A3 :    42→54%  +12.1   2.61   1.68   1/4     85   2.55 0.064 │    -2.5   1.14     114  0.0000 15.8448 │   0.775 │  1.11  -1.09
#   A4 :    42→54%  +11.9   2.60   3.63   0/4     89   3.94 0.051 │   -10.4   0.00       0  0.0000  2.8519 │   0.756 │  1.05  -0.58
#   A5 :    70→77%   +7.4   1.43   1.53   0/4     90   1.53 0.036 │    -3.9   0.00       0  0.0000  9.4619 │   0.257 │  0.91  -1.55
#   A6 :    71→86%  +14.9   1.29   1.50   0/4     89   1.50 0.070 │   -10.0   0.00       0  0.0000  5.2056 │   0.258 │  1.22  -0.32
#   A7 :    91→96%   +5.6   0.55   0.36   1/4     87   0.36 0.032 │    -2.2   0.17      17  0.0000 11.1291 │   0.000 │  1.01  -2.69
#   A8 :    92→95%   +3.1   0.54   0.42   0/4     92   0.47 0.020 │    -9.5   0.00       0  0.0000  5.8642 │   0.000 │  1.13   0.04
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep    98 │ price 40→54 (peak 54)  cap=   21  TNAC=   24 │ sec= 58.9€ vol=  6.8 match=75% │ ent=0.0300  shp=1.000  eps=0.247 [ENT-DECAY] [cyc=A3] [WARMUP 99/100]  │ warn: floor=2 bclust=2 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→23%   +2.6   5.15   4.28   0/4     51   8.76 0.009 │   -10.6   0.00       0  0.0000  8.7891 │   0.000 │  1.06   1.20
#   A2 :    21→26%   +4.7   5.00   4.44   0/4     53   6.53 0.051 │    -9.4   0.00       0  0.0000  2.3107 │   0.000 │  1.00   0.87
#   A3*:    43→46%   +3.0   3.11   1.04   1/4     48   2.74 0.033 │    -4.9   2.62     262  0.0000  9.3661 │   0.000 │  1.12  -0.29
#   A4 :    40→51%  +10.5   3.00   4.23   0/4     51   4.58 0.021 │    -7.4   0.00       0  0.0000  0.2129 │   0.000 │  1.04  -0.59
#   A5 :    72→77%   +5.2   1.42   1.50   0/4     57   1.50 0.048 │    -9.6   0.00       0  0.0000  1.6978 │   0.000 │  0.99   2.33
#   A6 :    76→81%   +4.2   1.19   1.30   0/4     57   1.30 0.036 │     0.5   0.00       0  0.0000 22.6695 │   0.000 │  0.95  -1.33
#   A7 :    91→96%   +4.8   0.55   0.65   2/4     50   0.68 0.031 │    -0.5   0.44      44  0.0000 10.6026 │   0.000 │  1.04  -1.17
#   A8 :   91→100%   +8.7   0.41   0.32   0/4     55   0.32 0.049 │    -2.4   0.00       0  0.0000  8.5678 │   0.000 │  1.00  -0.23
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   147 │ price 62→50 (peak 62)  cap=   21  TNAC=   22 │ sec= 43.4€ vol= 11.7 match=100% │ ent=0.0300  shp=1.000  eps=0.246 [ENT-DECAY] [cyc=A4]  │ warn: bclust=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→28%   +6.5   4.82   4.27   0/4     66   6.42 0.018 │   -10.3   0.00       0 -0.0174  4.1004 │   0.000 │  1.02   0.49
#   A2 :    20→23%   +3.4   5.15   3.96   0/4     60   5.96 0.045 │    -4.7   0.00       0 -0.0011  3.1770 │   0.000 │  1.12  -0.94
#   A3 :    41→48%   +6.8   3.07   3.64   0/4     64   3.64 0.065 │    -5.9   0.00       0 -0.0149  8.0969 │   0.000 │  0.98  -1.26
#   A4*:    41→45%   +4.3   3.27   2.79   0/4     69   4.23 0.038 │    -8.8   0.00       0  0.0454  0.5545 │   0.000 │  1.12  -1.08
#   A5 :    70→73%   +3.3   1.67   1.80   0/4     66   1.80 0.023 │    -7.3   0.00       0 -0.0036  1.9852 │   0.000 │  1.11  -0.44
#   A6 :    70→72%   +2.0   1.65   0.77   1/4     60   2.14 0.028 │    -4.5   0.03       3 -0.0044  4.5225 │   0.000 │  1.09   0.86
#   A7 :   91→100%   +9.4   0.50   0.28   1/4     67   0.28 0.058 │    -4.0   0.02       2 -0.0074  1.8532 │   0.000 │  1.09   1.02
#   A8 :    93→95%   +2.6   0.50   0.52   0/4     69   0.52 0.032 │    -8.3   0.00       0 -0.0006  1.4276 │   0.000 │  1.10  -0.12
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   196 │ price 48→48 (peak 51)  cap=   20  TNAC=   23 │ sec= 39.7€ vol= 13.3 match=80% │ ent=0.0300  shp=1.000  eps=0.244 [ENT-DECAY] [cyc=A5]  │ warn: cov<1=1 bclust=2 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→24%   +4.4   5.05   3.84   0/5     57   7.20 0.026 │    -9.6   0.00       0 -0.0115  0.5889 │   0.000 │  0.97  -1.86
#   A2 :    22→34%  +11.3   4.55   4.05   0/5     57   7.22 0.018 │   -11.8   0.00       0 -0.0118  3.0459 │   0.000 │  0.99  -1.94
#   A3 :    42→45%   +2.4   3.27   2.09   0/5     59   2.09 0.029 │    -7.0   0.00       0 -0.0064  3.7222 │   0.000 │  1.04  -2.40
#   A4 :    42→58%  +16.4   2.59   3.01   0/5     55   3.24 0.026 │    -9.2   0.00       0  0.0001  3.6171 │   0.000 │  0.88  -1.76
#   A5*:    70→74%   +3.9   1.55   1.10   1/5     58   1.40 0.043 │    -3.8   0.79      79 -0.0233  2.0533 │   0.000 │  0.87  -0.60
#   A6 :    70→78%   +7.7   1.46   1.43   0/5     54   1.43 0.026 │    -6.8   0.00       0 -0.0192  1.0879 │   0.000 │  0.92  -1.52
#   A7 :    91→95%   +4.3   0.51   0.43   0/5     55   0.43 0.022 │   -11.6   0.00       0 -0.0002  2.5569 │   0.000 │  1.06   0.35
#   A8 :    91→95%   +3.6   0.55   0.34   0/5     60   0.34 0.040 │    -8.6   0.00       0 -0.0041  0.1751 │   0.000 │  1.14  -1.27
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   245 │ price 95→74 (peak 95)  cap=   20  TNAC=   36 │ sec= 77.4€ vol= 12.0 match=100% │ ent=0.0300  shp=1.000  eps=0.243 [ENT-DECAY] [cyc=A6]  │ warn: chron=1 hoard=3
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→26%   +5.6   4.44   4.19   0/5     90   6.71 0.022 │   -14.4   0.00       0 -0.0094  9.3316 │   3.300 │  1.13  -0.86
#   A2 :    20→31%  +11.4   4.06   4.08   1/5     91   6.77 0.037 │    -7.0   0.02       2 -0.0048  6.5079 │   3.300 │  0.94  -2.55
#   A3 :    42→49%   +7.3   2.74   1.60   3/5     97   2.75 0.022 │    -0.8   2.02     202  0.0166 13.4273 │   1.474 │  1.00  -1.83
#   A4 :    40→42%   +1.8   2.98   4.71   0/5     99   5.75 0.004 │   -13.7   0.00       0  0.0069  6.7938 │   2.312 │  0.94  -1.17
#   A5 :    72→76%   +4.1   1.39   0.93   0/5     88   1.36 0.016 │    -8.2   0.00       0 -0.0083  1.3365 │   0.176 │  1.13  -1.86
#   A6*:    72→74%   +1.7   1.45   1.57   0/5     99   1.57 0.031 │   -11.0   0.00       0 -0.0144  5.6692 │   0.304 │  0.94  -2.28
#   A7 :    90→97%   +6.8   0.52   0.58   0/5     92   0.58 0.021 │   -11.0   0.00       0  0.0011  1.5145 │   0.000 │  0.99   0.32
#   A8 :    90→94%   +4.0   0.59   0.61   0/5     90   0.77 0.031 │   -10.6   0.00       0 -0.0027  0.7769 │   0.000 │  1.09  -0.23
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   294 │ price 48→61 (peak 65)  cap=   20  TNAC=   20 │ sec= 53.9€ vol=  8.6 match=60% │ ent=0.0300  shp=1.000  eps=0.242 [ENT-DECAY] [cyc=A7]  │ warn: chron=2 bclust=2 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→23%   +1.4   5.07   4.10   0/5     61   8.06 0.027 │    -6.4   0.00       0 -0.0406  0.8570 │   0.000 │  1.07  -0.95
#   A2 :    25→31%   +6.4   4.74   4.04   0/5     67   5.61 0.033 │   -12.9   0.00       0 -0.0015  2.2153 │   0.000 │  0.95  -1.83
#   A3 :    41→51%   +9.9   3.15   2.82   2/5     65   3.66 0.028 │    -2.4   0.31      31  0.0059  6.0197 │   0.000 │  1.06  -0.71
#   A4 :    40→44%   +3.8   3.46   3.76   0/5     70   4.40 0.008 │   -10.8   0.00       0 -0.0164  1.1385 │   0.000 │  0.93  -1.85
#   A5 :    70→82%  +12.4   1.31   1.08   3/5     63   1.30 0.035 │    -1.4   2.22     222 -0.0122  2.5655 │   0.000 │  0.80  -3.00
#   A6 :    70→72%   +2.1   1.64   1.60   0/5     65   2.04 0.020 │   -10.5   0.00       0 -0.0264  7.4162 │   0.000 │  1.01  -1.51
#   A7*:    92→95%   +3.4   0.52   0.44   0/5     68   0.44 0.011 │   -10.4   0.00       0 -0.0135  3.5843 │   0.000 │  1.08  -1.77
#   A8 :    91→94%   +2.7   0.58   0.19   4/5     60   0.52 0.024 │    -0.2   2.17     217  0.0015 28.7823 │   0.000 │  0.95  -2.44
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   343 │ price 78→73 (peak 78)  cap=   20  TNAC=   33 │ sec= 84.8€ vol= 12.8 match=100% │ ent=0.0300  shp=1.000  eps=0.240 [ENT-DECAY] [cyc=A8]  │ warn: bclust=2 hoard=4
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    21→22%   +1.5   4.50   2.83   0/5     77   7.77 0.045 │   -11.7   0.00       0 -0.0022  0.8150 │   3.300 │  1.07  -1.06
#   A2 :    20→36%  +16.5   3.94   3.74   0/5     91   6.43 0.029 │   -13.9   0.00       0 -0.0282  0.1888 │   3.300 │  0.93  -1.04
#   A3 :    41→46%   +4.5   2.83   3.15   0/5     90   3.64 0.007 │   -14.4   0.00       0 -0.0187  2.5260 │   1.804 │  1.12  -1.34
#   A4 :    42→51%   +9.3   2.69   3.16   0/5     83   3.95 0.043 │   -15.3   0.00       0 -0.0250  6.7742 │   1.238 │  1.10  -1.04
#   A5 :    74→78%   +3.2   1.33   1.29   0/5     89   1.29 0.006 │    -9.0   0.00       0  0.0048  1.8086 │   0.043 │  0.95  -1.48
#   A6 :    70→80%   +9.8   1.45   1.38   1/5     82   1.38 0.047 │    -7.1   0.43      43 -0.0053  4.2693 │   0.418 │  0.88  -2.44
#   A7 :   90→100%  +10.0   0.33   0.28   0/5     89   0.28 0.027 │    -7.6   0.00       0 -0.0194  0.5874 │   0.000 │  1.05  -1.48
#   A8*:    93→96%   +3.2   0.52   0.45   0/5     81   0.59 0.044 │   -13.5   0.00       0 -0.0024 13.4202 │   0.000 │  0.98   0.37
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   392 │ price 56→68 (peak 68)  cap=   20  TNAC=   18 │ sec= 67.6€ vol=  1.1 match=40% │ ent=0.0300  shp=1.000  eps=0.239 [ENT-DECAY] [cyc=A1]  │ warn: cov<1=1 chron=1 bclust=1 1side=3 0vol=3
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1*:    23→24%   +1.0   4.69   3.83   0/5     70   6.50 0.022 │   -11.4   0.00       0 -0.0000  2.2625 │   1.320 │  1.01  -1.11
#   A2 :    21→31%  +10.4   4.73   3.74   0/5     69   5.66 0.038 │    -9.4   0.00       0 -0.0161  0.9998 │   1.320 │  1.14  -2.76
#   A3 :    42→45%   +3.5   3.09   3.25   0/5     75   3.67 0.020 │   -12.1   0.00       0 -0.0100  0.1873 │   0.638 │  0.92  -2.60
#   A4 :    43→44%   +0.8   3.12   4.25   0/5     76   5.05 0.000 │   -14.4   0.00       0 -0.0236  1.1816 │   0.756 │  0.90  -2.63
#   A5 :    74→86%  +12.2   1.23   0.83   1/5     60   1.43 0.035 │    -5.2   0.40      40  0.0114  1.9823 │   0.000 │  0.99  -2.71
#   A6 :    72→87%  +15.2   1.30   0.87   0/5     72   1.20 0.019 │    -2.7   0.00       0 -0.0197 13.0019 │   0.000 │  0.80  -3.00
#   A7 :    91→99%   +8.7   0.53   0.47   0/5     72   0.47 0.037 │   -10.3   0.00       0 -0.0035  1.7235 │   0.000 │  1.27  -3.00
#   A8 :   91→100%   +8.8   0.45   0.31   3/5     67   0.42 0.011 │     1.5   0.81      81  0.0035 34.8538 │   0.000 │  1.10  -1.65
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   441 │ price 70→66 (peak 70)  cap=   20  TNAC=   24 │ sec= 66.2€ vol=  4.8 match=80% │ ent=0.0300  shp=1.000  eps=0.237 [ENT-DECAY] [cyc=A2]  │ warn: chron=2 bclust=3 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    23→33%   +9.3   4.19   4.22   0/5     70   6.92 0.030 │   -14.9   0.00       0 -0.0090  9.6213 │   1.980 │  1.06  -1.40
#   A2*:    20→29%   +8.8   4.61   3.85   0/5     66   5.53 0.041 │    -7.8   0.00       0 -0.1230  3.8482 │   1.980 │  1.18  -1.21
#   A3 :    42→42%   +0.0   3.09   3.45   0/5     71   4.22 0.020 │   -16.0   0.00       0 -0.0030  6.8299 │   1.257 │  1.10  -1.05
#   A4 :    42→43%   +0.7   3.07   3.35   0/5     67   4.01 0.045 │   -16.3   0.00       0  0.0002 11.4916 │   1.234 │  0.91  -2.96
#   A5 :    70→78%   +8.4   1.35   0.60   5/5     71   1.07 0.004 │    -2.4   5.61     561 -0.0060  4.5070 │   0.165 │  0.91  -1.49
#   A6 :    73→75%   +2.6   1.41   1.24   0/5     71   1.36 0.000 │   -12.4   0.00       0 -0.0024  6.9357 │   0.104 │  0.96  -2.04
#   A7 :    91→97%   +5.9   0.51   0.33   0/5     65   0.37 0.019 │   -10.1   0.00       0 -0.0158  1.6263 │   0.000 │  1.07  -1.41
#   A8 :   91→100%   +9.0   0.39   0.15   5/5     67   0.31 0.015 │     1.2   1.26     126  0.0098 25.1153 │   0.000 │  0.96  -0.71
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   490 │ price 70→95 (peak 118)  cap=   20  TNAC=   35 │ sec= 90.1€ vol=  9.4 match=80% │ ent=0.0300  shp=1.000  eps=0.236 [ENT-DECAY] [cyc=A3]  │ warn: ceil=2 cov<1=1 chron=1 bclust=1 hoard=1 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    21→27%   +5.7   4.20   4.46   0/5    106   6.19 0.007 │   -16.1   0.00       0 -0.0197  4.8113 │   3.300 │  1.00  -1.35
#   A2 :    22→33%  +11.3   4.20   3.36   0/5    101   6.34 0.031 │    -9.3   0.00       0 -0.0015  2.3544 │   3.300 │  1.20  -2.30
#   A3*:    42→52%  +10.2   2.73   3.36   0/5    108   3.36 0.048 │   -12.6   0.00       0 -0.0717  3.6656 │   1.425 │  0.96  -0.97
#   A4 :    42→47%   +4.6   2.81   4.23   0/5    100   4.95 0.034 │   -14.2   0.00       0 -0.0238  0.8135 │   1.688 │  0.92  -1.91
#   A5 :    73→76%   +3.5   1.41   1.25   0/5    101   1.42 0.032 │    -8.5   0.00       0 -0.0354  0.1352 │   0.155 │  1.05  -2.39
#   A6 :    71→88%  +17.2   1.22   0.87   0/5    104   1.18 0.044 │   -10.5   0.00       0 -0.0368  3.3135 │   0.146 │  1.04  -1.15
#   A7 :    92→94%   +1.8   0.53   0.26   4/5    109   0.26 0.015 │    -1.1   1.67     167 -0.0263  9.6670 │   0.000 │  1.22  -2.37
#   A8 :    92→94%   +1.4   0.52   0.33   0/5    108   0.44 0.010 │   -10.2   0.00       0 -0.0178  3.4264 │   0.000 │  1.12  -1.82
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   539 │ price 61→53 (peak 61)  cap=   20  TNAC=   19 │ sec= 48.5€ vol= 16.7 match=100% │ ent=0.0300  shp=1.000  eps=0.235 [ENT-DECAY] [cyc=A4]  │ warn: bclust=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→37%  +15.6   4.52   4.23   1/5     70   7.01 0.011 │    -0.5   0.86      86 -0.0285 30.7300 │   0.000 │  1.11  -2.56
#   A2 :    20→21%   +1.2   5.22   3.82   0/5     67   6.60 0.027 │   -13.4   0.00       0 -0.0061  2.5603 │   0.000 │  1.07  -0.86
#   A3 :    43→55%  +12.7   2.75   3.09   0/5     70   3.31 0.021 │   -10.4   0.00       0 -0.0144  0.4846 │   0.000 │  0.92  -1.80
#   A4*:    42→62%  +19.7   2.76   2.47   0/5     60   2.70 0.056 │   -10.7   0.00       0  0.0071  1.2092 │   0.000 │  0.99  -1.48
#   A5 :    70→81%  +10.9   1.45   1.61   0/5     71   1.61 0.006 │    -4.9   0.00       0 -0.0014  6.7948 │   0.000 │  1.03  -1.70
#   A6 :    73→77%   +4.1   1.38   0.89   0/5     67   1.13 0.024 │    -8.4   0.00       0 -0.0064  4.7248 │   0.000 │  0.92   0.45
#   A7 :    94→95%   +1.5   0.47   0.38   0/5     70   0.38 0.000 │    -9.4   0.00       0  0.0076  1.6982 │   0.000 │  1.19  -1.97
#   A8 :    90→95%   +5.0   0.53   0.41   0/5     66   0.41 0.008 │   -10.8   0.00       0 -0.0682  1.1062 │   0.000 │  1.14  -1.86
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   588 │ price 63→67 (peak 67)  cap=   19  TNAC=   20 │ sec= 68.8€ vol= 18.6 match=100% │ ent=0.0300  shp=1.000  eps=0.233 [ENT-DECAY] [cyc=A5]  │ warn: cov<1=1 chron=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    23→33%  +10.1   4.34   3.88   0/6     72   5.55 0.003 │   -16.0   0.00       0 -0.0164  0.2577 │   0.660 │  1.03  -2.08
#   A2 :    22→37%  +15.3   4.38   3.40   4/6     68   6.54 0.045 │    -7.3   5.65     565 -0.0081 15.9191 │   0.660 │  1.19  -1.73
#   A3 :    44→55%  +10.7   2.62   2.76   0/6     74   3.01 0.010 │   -12.1   0.00       0 -0.0065  6.4905 │   0.006 │  1.01  -2.20
#   A4 :    45→58%  +13.4   2.79   4.11   0/6     71   4.78 0.015 │    -7.3   0.00       0 -0.0342 12.8391 │   0.000 │  0.86  -2.34
#   A5*:    71→79%   +7.8   1.31   0.92   0/6     67   0.99 0.014 │   -12.0   0.00       0  0.0124  9.2635 │   0.000 │  0.99  -0.94
#   A6 :    73→86%  +13.9   1.01   0.63   0/6     66   0.93 0.017 │   -14.9   0.00       0 -0.0323 17.1583 │   0.000 │  1.13  -0.31
#   A7 :    90→93%   +3.2   0.59   0.27   1/6     68   0.39 0.016 │    -9.2   0.33      33 -0.0318  0.9337 │   0.000 │  1.19  -1.62
#   A8 :    90→95%   +5.0   0.55   0.24   0/6     66   0.32 0.000 │   -16.2   0.00       0 -0.0265 12.5325 │   0.000 │  1.04   0.40
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   637 │ price 50→53 (peak 67)  cap=   19  TNAC=   16 │ sec= 52.6€ vol=  9.4 match=83% │ ent=0.0300  shp=1.000  eps=0.232 [ENT-DECAY] [cyc=A6]  │ warn: cov<1=1 chron=2 bclust=2 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→22%   +0.0   5.04   4.23   1/6     62   6.28 0.029 │    -9.2   0.18      18 -0.0359  1.2548 │   0.660 │  1.13  -2.19
#   A2 :    20→24%   +3.6   5.04   4.00   0/6     67   5.52 0.015 │   -10.3   0.00       0 -0.0285  0.8055 │   0.660 │  1.15  -0.31
#   A3 :    42→58%  +15.2   2.71   3.05   0/6     65   3.14 0.049 │   -15.1   0.00       0 -0.0064  0.5677 │   0.034 │  1.07  -1.75
#   A4 :    40→50%   +9.5   3.28   3.88   0/6     62   4.33 0.025 │   -15.6   0.00       0 -0.0119  4.1539 │   0.428 │  1.01  -1.76
#   A5 :    72→80%   +8.3   1.31   0.62   4/6     65   0.92 0.023 │    -5.3   2.97     297 -0.0066  6.7403 │   0.000 │  1.03  -2.20
#   A6*:    70→74%   +3.6   1.54   1.48   3/6     67   1.48 0.021 │    -5.4   1.78     178 -0.0598  2.1025 │   0.046 │  0.87  -2.96
#   A7 :    91→95%   +3.8   0.50   0.23   0/6     64   0.23 0.030 │    -7.7   0.00       0 -0.0238  1.3754 │   0.000 │  1.24  -1.55
#   A8 :    90→93%   +3.1   0.63   0.53   2/6     62   0.53 0.014 │    -7.3   0.10      10 -0.0288  4.5444 │   0.000 │  1.17  -1.64
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   686 │ price 51→65 (peak 66)  cap=   19  TNAC=   16 │ sec= 67.7€ vol= 10.5 match=100% │ ent=0.0300  shp=1.000  eps=0.230 [ENT-DECAY] [cyc=A7]  │ warn: chron=1 bclust=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→24%   +3.8   5.05   4.19   0/6     69   5.37 0.020 │   -13.5   0.00       0 -0.0140  0.6394 │   0.660 │  0.94  -1.81
#   A2 :    23→26%   +2.7   4.80   4.18   0/6     71   7.54 0.008 │   -10.4   0.00       0 -0.0316  0.2176 │   0.660 │  1.18  -1.95
#   A3 :    41→45%   +3.8   3.16   3.40   0/6     71   3.75 0.025 │   -13.6   0.00       0 -0.0077  0.4203 │   0.384 │  0.86  -2.25
#   A4 :    41→43%   +1.8   3.26   3.69   0/6     70   4.89 0.017 │   -14.1   0.00       0 -0.0436  2.6352 │   0.396 │  0.80  -2.25
#   A5 :    71→76%   +5.3   1.48   0.89   0/6     68   1.36 0.015 │   -14.6   0.00       0 -0.0112  4.2321 │   0.020 │  1.11   0.05
#   A6 :    70→80%   +9.9   1.54   0.94   1/6     65   1.65 0.043 │    -8.9   0.27      27 -0.0254  2.1232 │   0.109 │  0.92  -1.77
#   A7*:    91→95%   +3.7   0.53   0.25   4/6     68   0.28 0.012 │    -0.3   1.26     126  0.0214 24.1052 │   0.000 │  1.30  -3.00
#   A8 :   91→100%   +8.7   0.48   0.31   1/6     65   0.44 0.026 │   -11.0   0.11      11  0.0059  3.3984 │   0.000 │  1.15  -1.35
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   735 │ price 59→55 (peak 59)  cap=   19  TNAC=   20 │ sec= 54.7€ vol=  6.0 match=50% │ ent=0.0300  shp=1.000  eps=0.229 [ENT-DECAY] [cyc=A8]  │ warn: chron=1 bclust=1 1side=3 0vol=3
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→25%   +3.4   4.94   4.56   0/6     69   9.01 0.000 │   -12.8   0.00       0  0.0017  0.5313 │   0.000 │  1.11  -1.81
#   A2 :    21→38%  +16.8   4.50   3.71   1/6     62   5.19 0.041 │    -9.3   1.13     113 -0.0299  5.8457 │   0.000 │  1.29  -2.32
#   A3 :    40→46%   +5.7   3.19   4.13   0/6     68   4.77 0.001 │   -17.1   0.00       0 -0.0080  2.7978 │   0.000 │  0.89  -1.38
#   A4 :    42→48%   +5.9   2.97   3.29   0/6     56   4.33 0.068 │   -18.7   0.00       0 -0.0316  2.9733 │   0.000 │  0.88  -3.00
#   A5 :    72→87%  +15.2   1.16   0.81   0/6     63   1.21 0.043 │    -8.4   0.00       0 -0.0057  2.6401 │   0.000 │  0.95  -1.84
#   A6 :    71→92%  +21.1   1.04   0.37   2/6     65   0.64 0.024 │    -4.2   0.57      57  0.0243  7.2011 │   0.000 │  0.93  -1.65
#   A7 :    92→95%   +2.8   0.51   0.24   3/6     63   0.37 0.022 │    -3.0   0.77      77 -0.0145 10.8292 │   0.000 │  1.24  -2.54
#   A8*:   92→100%   +8.2   0.49   0.30   3/6     67   0.30 0.015 │    -5.3   0.86      86 -0.0531  5.2659 │   0.000 │  1.25  -2.63
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   784 │ price 53→63 (peak 84)  cap=   19  TNAC=   29 │ sec= 62.6€ vol= 13.3 match=100% │ ent=0.0300  shp=1.000  eps=0.228 [ENT-DECAY] [cyc=A1]  │ warn: cov<1=1 chron=2 bclust=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1*:    21→33%  +12.8   4.11   3.69   0/6     69   4.99 0.037 │   -17.9   0.00       0 -0.0649  2.9487 │   2.640 │  1.02   0.53
#   A2 :    23→35%  +11.5   3.92   3.62   0/6     76   4.96 0.019 │   -10.9   0.00       0  0.0090  0.9545 │   2.640 │  1.07  -1.02
#   A3 :    40→42%   +2.2   3.11   3.69   0/6     80   4.62 0.015 │   -13.4   0.00       0 -0.0388  1.1285 │   1.770 │  0.95  -1.69
#   A4 :    50→55%   +4.9   2.50   3.77   0/6     76   4.14 0.024 │   -16.3   0.00       0 -0.0535  0.5295 │   0.322 │  1.09  -0.82
#   A5 :    71→78%   +6.5   1.33   0.86   0/6     80   0.86 0.000 │   -14.0   0.00       0 -0.0189 17.9160 │   0.000 │  1.06  -0.61
#   A6 :    70→70%   +0.0   1.66   1.05   2/6     77   1.05 0.021 │    -6.5   1.09     109 -0.0458  0.6565 │   0.660 │  0.96  -1.15
#   A7 :    90→95%   +4.9   0.54   0.25   3/6     76   0.31 0.005 │    -3.4   0.83      83 -0.0608 15.3422 │   0.000 │  1.19  -2.77
#   A8 :    91→98%   +7.0   0.49   0.24   4/6     76   0.42 0.034 │     0.0   0.72      72 -0.0102 33.2229 │   0.000 │  1.27  -2.03
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   833 │ price 57→46 (peak 57)  cap=   19  TNAC=   20 │ sec= 40.2€ vol=  6.0 match=83% │ ent=0.0300  shp=1.000  eps=0.226 [ENT-DECAY] [cyc=A2]  │ warn: 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→29%   +9.0   4.77   3.37   0/6     58   5.78 0.028 │   -16.5   0.00       0 -0.0183  3.4782 │   0.000 │  1.07  -0.65
#   A2*:    20→30%  +10.0   4.73   4.10   0/6     55   5.75 0.032 │   -15.6   0.00       0  0.0599  0.5480 │   0.000 │  1.11  -2.62
#   A3 :    40→51%  +11.2   2.90   3.08   0/6     57   3.87 0.021 │    -8.3   0.00       0 -0.0727 14.5831 │   0.000 │  0.91  -2.13
#   A4 :    41→47%   +5.4   3.10   4.12   0/6     63   5.87 0.000 │   -15.2   0.00       0 -0.0287  0.2222 │   0.000 │  0.84  -2.13
#   A5 :    70→82%  +11.9   1.38   1.05   2/6     57   1.17 0.008 │    -2.6   0.20      20 -0.0219 21.0837 │   0.000 │  1.14  -2.49
#   A6 :    72→90%  +17.3   1.19   1.00   0/6     59   1.00 0.055 │   -14.7   0.00       0 -0.0169 14.9480 │   0.000 │  0.93  -1.60
#   A7 :   93→100%   +6.7   0.39   0.28   0/6     58   0.28 0.029 │    -7.0   0.00       0 -0.0086  0.9460 │   0.000 │  1.11  -2.82
#   A8 :   90→100%  +10.0   0.55   0.28   0/6     64   0.28 0.016 │   -10.4   0.00       0 -0.0269  4.4885 │   0.000 │  1.16  -1.77
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   882 │ price 66→67 (peak 85)  cap=   19  TNAC=   26 │ sec= 73.8€ vol= 17.2 match=83% │ ent=0.0300  shp=1.000  eps=0.225 [ENT-DECAY] [cyc=A3]  │ warn: bclust=1 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→36%  +13.5   3.92   3.92   0/6     78   5.42 0.032 │   -18.5   0.00       0 -0.0059  4.2505 │   3.960 │  0.98  -0.56
#   A2 :    21→31%  +10.4   4.23   3.75   0/6     83   5.58 0.030 │   -13.2   0.00       0 -0.0299  1.4791 │   3.960 │  1.03  -1.34
#   A3*:    43→47%   +4.4   2.76   3.73   0/6     83   4.24 0.012 │   -18.2   0.00       0 -0.0284  5.4683 │   1.840 │  1.05  -1.19
#   A4 :    42→45%   +3.2   2.85   3.37   0/6     85   4.63 0.018 │    -9.8   0.00       0 -0.0485  8.1663 │   2.213 │  0.90  -1.41
#   A5 :    70→79%   +9.4   1.38   0.84   2/6     85   1.27 0.029 │    -6.9   1.09     109 -0.0381  4.2942 │   0.495 │  1.20  -1.87
#   A6 :    75→76%   +0.8   1.33   0.43   3/6     87   0.85 0.010 │    -6.1   2.44     244  0.0073  0.8714 │   0.000 │  1.00  -0.91
#   A7 :    90→99%   +8.9   0.42   0.29   0/6     84   0.29 0.041 │   -10.2   0.00       0 -0.0435  3.3669 │   0.000 │  1.09  -1.34
#   A8 :   90→100%  +10.0   0.37   0.18   2/6     81   0.22 0.018 │    -0.8   0.23      23 -0.0191  8.5507 │   0.000 │  1.21  -2.05
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   931 │ price 67→62 (peak 67)  cap=   19  TNAC=   21 │ sec= 66.4€ vol=  8.3 match=83% │ ent=0.0300  shp=1.000  eps=0.223 [ENT-DECAY] [cyc=A4]  │ warn: chron=2 bclust=2 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    24→32%   +8.0   4.41   4.10   0/6     69   7.71 0.009 │    -7.7   0.00       0 -0.0218 20.9568 │   0.660 │  1.16  -2.63
#   A2 :    22→26%   +4.2   4.88   3.42   1/6     71   4.59 0.017 │    -9.7   1.33     133 -0.0081  8.4131 │   0.660 │  1.11  -2.13
#   A3 :    40→46%   +5.8   3.08   3.98   0/6     71   4.67 0.019 │   -18.1   0.00       0 -0.0480  4.6809 │   0.495 │  0.94  -0.95
#   A4*:    44→59%  +14.4   2.90   3.49   0/6     68   3.96 0.030 │   -18.1   0.00       0  0.0074  2.0763 │   0.350 │  0.96  -1.22
#   A5 :    72→85%  +13.7   1.26   0.58   5/6     71   1.08 0.014 │    -2.4   5.02     502 -0.0117  9.7997 │   0.108 │  1.23  -1.90
#   A6 :    71→78%   +7.8   1.38   0.85   5/6     70   1.74 0.015 │    -3.1   4.26     426 -0.0082  1.7347 │   0.144 │  0.80  -3.00
#   A7 :    90→91%   +1.3   0.63   0.43   1/6     69   0.43 0.028 │    -7.2   0.11      11 -0.0419  7.1934 │   0.000 │  1.22  -1.46
#   A8 :    93→95%   +2.1   0.49   0.22   0/6     69   0.22 0.013 │   -14.3   0.00       0  0.0155 24.6432 │   0.000 │  1.18  -1.22
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   980 │ price 62→75 (peak 75)  cap=   18  TNAC=   21 │ sec= 74.9€ vol=  7.9 match=71% │ ent=0.0300  shp=1.000  eps=0.222 [ENT-DECAY] [cyc=A5]  │ warn: chron=2 bclust=2 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→43%  +21.3   4.32   4.02   0/7     75   6.90 0.028 │   -19.4   0.00       0  0.2358  0.7223 │   1.872 │  1.15  -2.70
#   A2 :    21→29%   +7.8   4.79   4.38   0/7     73   7.92 0.024 │   -12.3   0.00       0 -0.0702  2.0512 │   1.980 │  1.06  -1.29
#   A3 :    42→54%  +11.2   2.86   2.92   0/7     73   3.79 0.038 │   -19.7   0.00       0 -0.4216  0.3951 │   0.144 │  0.95  -0.40
#   A4 :    40→55%  +15.2   2.92   3.25   2/7     72   4.78 0.015 │    -7.4   0.51      51 -1.0796 59.0834 │   0.299 │  0.91  -2.00
#   A5*:    71→71%   +0.0   1.61   1.71   0/7     76   1.71 0.010 │   -18.4   0.00       0  0.4924  8.8939 │   0.358 │  0.96  -2.04
#   A6 :    72→91%  +19.4   1.08   0.77   5/7     76   1.13 0.014 │    -0.4   3.08     308 -0.3057 12.8815 │   0.000 │  0.84  -2.57
#   A7 :    91→94%   +3.3   0.58   0.31   0/7     68   0.48 0.030 │   -15.2   0.00       0 -0.7190  8.2621 │   0.000 │  1.22  -1.43
#   A8 :   91→100%   +9.5   0.35   0.14   4/7     78   0.14 0.010 │    -0.5   0.78      78  0.0464 18.7806 │   0.000 │  1.24  -2.17
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1029 │ price 51→76 (peak 83)  cap=   18  TNAC=   26 │ sec= 67.8€ vol= 14.5 match=86% │ ent=0.0300  shp=1.000  eps=0.221 [ENT-DECAY] [cyc=A6]  │ warn: bclust=2 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    28→33%   +4.8   3.94   3.95   0/7     82   7.11 0.013 │   -19.0   0.00       0  0.6357  4.7034 │   3.300 │  0.95  -2.50
#   A2 :    24→38%  +13.6   4.01   3.54   1/7     77   5.82 0.029 │    -9.0   0.03       3 -0.0481  3.1007 │   3.300 │  1.03  -1.79
#   A3 :    41→45%   +4.5   2.95   3.41   0/7     78   4.60 0.019 │   -18.9   0.00       0  0.3443  8.6184 │   1.616 │  1.04  -1.56
#   A4 :    40→49%   +9.0   2.84   3.53   0/7     80   4.15 0.036 │   -17.7   0.00       0  0.6029  3.9987 │   1.095 │  0.94  -1.79
#   A5 :   75→100%  +25.4   0.95   0.38   0/7     69   1.05 0.044 │   -18.9   0.00       0 -0.2817  5.9673 │   0.000 │  1.01   0.53
#   A6*:    70→84%  +13.7   1.39   1.17   0/7     79   1.17 0.019 │   -17.4   0.00       0  0.4656 10.7804 │   0.076 │  1.09  -1.46
#   A7 :    94→97%   +3.0   0.43   0.23   1/7     81   0.28 0.010 │   -10.2   0.02       2  0.1706  1.0976 │   0.000 │  1.18  -2.00
#   A8 :   92→100%   +8.0   0.39   0.26   0/7     74   0.33 0.020 │   -14.4   0.00       0 -0.0976  4.6654 │   0.000 │  1.26  -2.64
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1078 │ price 66→97 (peak 111)  cap=   18  TNAC=   34 │ sec= 78.3€ vol= 23.1 match=100% │ ent=0.0300  shp=1.000  eps=0.219 [ENT-DECAY] [cyc=A7]  │ warn: ceil=1 cov<1=1 chron=1 bclust=1 hoard=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    26→42%  +16.1   3.56   3.82   0/7     92   6.94 0.037 │   -16.0   0.00       0  0.2543  9.1263 │   4.547 │  1.09  -2.81
#   A2 :    21→23%   +1.5   4.41   3.93   0/7     98   5.99 0.008 │   -21.9   0.00       0 -0.3434 15.9125 │   4.620 │  1.02   0.06
#   A3 :    42→42%   +0.0   2.93   4.59   0/7     98   5.98 0.000 │   -19.8   0.00       0 -0.1738  7.6515 │   2.987 │  0.89  -2.92
#   A4 :    43→55%  +11.9   2.56   3.87   0/7     94   4.36 0.008 │   -19.9   0.00       0 -0.1464  2.2718 │   1.156 │  0.98  -1.72
#   A5 :    72→89%  +17.0   1.11   0.58   1/7     90   0.88 0.025 │   -11.5   0.38      38 -0.2899  5.9455 │   0.091 │  1.10  -0.92
#   A6 :    70→91%  +20.7   0.98   0.47   2/7     88   1.13 0.043 │    -8.1   0.63      63 -0.3657  3.8882 │   0.233 │  0.90  -2.26
#   A7*:   92→100%   +8.1   0.38   0.33   0/7     92   0.36 0.027 │   -19.7   0.00       0  0.0783 21.4924 │   0.000 │  0.92   1.32
#   A8 :   92→100%   +7.5   0.43   0.24   3/7     91   0.33 0.021 │    -1.2   1.21     121  0.1848  7.6650 │   0.000 │  1.23  -2.68
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1127 │ price 56→87 (peak 87)  cap=   18  TNAC=   21 │ sec= 86.6€ vol= 17.9 match=86% │ ent=0.0300  shp=1.000  eps=0.218 [ENT-DECAY] [cyc=A8]  │ warn: chron=1 bclust=2 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    23→32%   +8.9   4.23   4.44   0/7     75   7.71 0.018 │   -11.9   0.00       0  0.5502  4.5540 │   1.980 │  1.17  -2.53
#   A2 :    23→25%   +2.3   4.62   3.98   1/7     70   7.18 0.028 │   -13.5   0.19      19  0.1422  3.8213 │   1.980 │  0.99  -1.14
#   A3 :    42→54%  +11.7   2.93   3.45   0/7     74   3.99 0.015 │   -18.9   0.00       0  0.2038  6.9109 │   0.398 │  0.96  -2.43
#   A4 :    44→56%  +11.7   2.87   3.33   0/7     70   4.08 0.016 │   -15.7   0.00       0 -0.7109  5.2874 │   0.428 │  0.93  -1.61
#   A5 :    71→76%   +4.4   1.45   1.25   2/7     74   1.85 0.014 │    -6.6   0.82      82 -0.1992  2.8904 │   0.000 │  1.15  -1.06
#   A6 :    72→77%   +5.4   1.31   0.54   2/7     67   1.43 0.045 │   -12.6   2.53     253  0.6934 10.1734 │   0.000 │  0.92  -1.16
#   A7 :    91→94%   +3.2   0.63   0.35   0/7     74   0.40 0.020 │   -19.9   0.00       0 -0.4346 25.5171 │   0.000 │  1.10   0.35
#   A8*:   92→100%   +8.0   0.45   0.21   5/7     74   0.29 0.022 │    -1.1   1.58     158  0.5942  2.9030 │   0.000 │  1.15  -2.50
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1176 │ price 47→49 (peak 60)  cap=   18  TNAC=   26 │ sec= 49.0€ vol=  9.7 match=71% │ ent=0.0300  shp=1.000  eps=0.216 [ENT-DECAY] [cyc=A1]  │ warn: cov<1=2 chron=3 bclust=3 1side=1 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1*:    25→53%  +28.1   3.71   3.26   0/7     55   5.14 0.045 │   -18.7   0.00       0 -0.7730  6.1604 │   0.000 │  0.96  -0.58
#   A2 :    24→29%   +5.4   4.79   3.24   0/7     61   5.35 0.037 │   -17.5   0.00       0 -0.5967  1.3826 │   0.000 │  1.01  -0.99
#   A3 :    46→61%  +14.4   2.36   2.85   0/7     59   3.12 0.017 │   -18.5   0.00       0 -1.2457  4.5095 │   0.000 │  1.02  -1.83
#   A4 :    42→62%  +19.4   2.75   3.13   0/7     62   3.46 0.032 │   -15.7   0.00       0  0.5144  1.0139 │   0.000 │  0.89  -2.21
#   A5 :    77→91%  +14.1   0.87   0.52   6/7     60   0.52 0.012 │    -0.7   2.14     214  0.5935 16.4672 │   0.000 │  1.24  -2.63
#   A6 :    72→77%   +4.6   1.55   1.45   0/7     60   1.45 0.044 │   -18.8   0.00       0 -0.0023 10.7947 │   0.000 │  0.93  -2.30
#   A7 :    90→97%   +7.0   0.54   0.49   0/7     62   0.55 0.020 │   -15.3   0.00       0 -0.5670  5.2047 │   0.000 │  1.18  -2.87
#   A8 :   92→100%   +7.7   0.36   0.19   5/7     60   0.21 0.029 │     0.7   0.93      93 -0.2150 16.6286 │   0.000 │  1.30  -3.00
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1225 │ price 48→65 (peak 65)  cap=   18  TNAC=   17 │ sec= 59.0€ vol= 15.5 match=100% │ ent=0.0300  shp=1.000  eps=0.215 [ENT-DECAY] [cyc=A2]  │ warn: chron=3 bclust=3
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    24→25%   +1.1   4.82   4.14   0/7     60   7.93 0.011 │   -17.8   0.00       0 -0.0641  6.2025 │   0.660 │  1.06  -0.73
#   A2*:    20→32%  +11.6   4.80   3.78   0/7     58   6.97 0.041 │   -12.2   0.00       0 -0.1479 14.1010 │   0.660 │  1.11  -0.70
#   A3 :    45→49%   +3.3   2.89   3.07   0/7     58   3.83 0.006 │   -19.1   0.00       0 -0.1351  4.6167 │   0.206 │  1.03  -1.53
#   A4 :    42→53%  +11.3   3.13   3.53   0/7     57   4.63 0.024 │   -17.2   0.00       0  0.2738  1.3047 │   0.060 │  1.06  -1.14
#   A5 :    70→79%   +9.4   1.45   1.66   0/7     60   1.66 0.009 │    -9.6   0.00       0 -0.5698  5.8177 │   0.000 │  1.06  -1.86
#   A6 :    70→84%  +14.2   1.24   1.01   2/7     57   1.13 0.046 │   -12.2   1.21     121  0.7315  2.3784 │   0.000 │  0.98  -1.60
#   A7 :    90→93%   +3.3   0.58   0.37   5/7     58   0.42 0.022 │    -1.0   1.99     199 -0.4791  8.1158 │   0.000 │  1.30  -3.00
#   A8 :    94→95%   +1.1   0.47   0.14   6/7     58   0.28 0.002 │     0.3   2.84     284  0.0849 10.5806 │   0.000 │  1.23  -2.89
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1274 │ price 57→63 (peak 66)  cap=   18  TNAC=   21 │ sec= 64.5€ vol= 13.5 match=86% │ ent=0.0300  shp=1.000  eps=0.214 [ENT-DECAY] [cyc=A3]  │ warn: chron=2 bclust=2 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→36%  +13.9   4.41   3.36   0/7     70   6.00 0.026 │   -17.8   0.00       0 -0.3969  2.2299 │   0.660 │  0.99  -0.71
#   A2 :    22→23%   +1.0   4.98   3.76   0/7     68   9.01 0.026 │   -15.1   0.00       0 -0.6585  1.7967 │   0.660 │  1.07  -0.47
#   A3*:    41→44%   +3.4   3.20   3.32   0/7     66   4.44 0.019 │   -13.1   0.00       0 -0.6092 10.0479 │   0.360 │  0.93  -1.42
#   A4 :    45→47%   +1.9   3.01   4.20   0/7     72   5.51 0.006 │   -20.7   0.00       0  0.4552  4.6253 │   0.277 │  1.04  -2.19
#   A5 :    70→96%  +25.6   1.18   0.90   0/7     67   1.22 0.039 │   -15.1   0.00       0 -0.4601  3.7197 │   0.000 │  1.09  -1.99
#   A6 :    70→98%  +27.8   1.06   0.73   0/7     61   1.23 0.034 │   -10.6   0.00       0 -0.6603  7.2355 │   0.000 │  1.04  -1.67
#   A7 :   92→100%   +7.9   0.37   0.18   6/7     67   0.20 0.016 │     1.1   1.30     130  0.3715 15.4499 │   0.000 │  1.27  -2.83
#   A8 :   91→100%   +9.2   0.47   0.36   1/7     68   0.36 0.021 │    -4.6   0.02       2 -0.0786  1.5844 │   0.000 │  1.24  -2.87
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1323 │ price 73→51 (peak 86)  cap=   17  TNAC=   21 │ sec= 66.4€ vol= 12.4 match=75% │ ent=0.0300  shp=1.000  eps=0.212 [ENT-DECAY] [cyc=A4]  │ warn: chron=5 bclust=1 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→23%   +2.8   4.76   4.06   3/8     78   8.50 0.016 │   -17.2   4.96     496 -0.0039  0.5957 │   2.640 │  1.12  -1.90
#   A2 :    21→33%  +11.7   4.46   3.53   0/8     80   7.06 0.012 │   -10.9   0.00       0 -0.1697  3.1535 │   2.640 │  1.22   0.11
#   A3 :    43→48%   +5.1   2.96   3.64   0/8     80   4.21 0.010 │   -23.7   0.00       0 -0.3084  2.7026 │   1.474 │  1.05  -1.84
#   A4*:    40→57%  +17.3   2.79   3.08   0/8     73   4.91 0.043 │   -24.7   0.00       0 -0.3262  0.7756 │   1.732 │  1.08  -0.45
#   A5 :    70→82%  +11.6   1.27   1.36   0/8     81   1.62 0.006 │   -11.3   0.00       0 -0.3456 13.9571 │   0.388 │  1.08  -2.14
#   A6 :    71→81%  +10.5   1.18   1.02   5/8     82   1.02 0.017 │    -5.5   4.24     424 -0.4909  5.7381 │   0.144 │  0.87  -2.62
#   A7 :   91→100%   +8.7   0.30   0.22   6/8     75   0.29 0.016 │     5.5   0.75      75  0.2514 13.3416 │   0.000 │  1.25  -2.87
#   A8 :   92→100%   +8.5   0.42   0.14   8/8     70   0.47 0.033 │     1.3   2.94     294 -0.1600 28.3263 │   0.000 │  1.24  -2.52
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1372 │ price 84→75 (peak 91)  cap=   17  TNAC=   32 │ sec= 86.0€ vol= 19.9 match=75% │ ent=0.0300  shp=1.000  eps=0.211 [ENT-DECAY] [cyc=A5]  │ warn: chron=1 bclust=1 hoard=1 1side=1 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    26→41%  +14.8   3.61   2.77   0/8     89   6.60 0.035 │   -21.8   0.00       0 -0.1290  9.9705 │   5.230 │  1.09  -0.78
#   A2 :    23→29%   +5.9   4.04   3.55   0/8     94   6.28 0.025 │   -22.1   0.00       0 -0.4326  6.2281 │   5.280 │  1.08  -1.44
#   A3 :    42→47%   +4.8   2.82   3.68   0/8     94   4.52 0.021 │   -25.7   0.00       0 -0.0750  6.0510 │   2.767 │  1.05  -1.47
#   A4 :    40→48%   +8.1   2.89   3.98   0/8     93   5.34 0.021 │   -25.8   0.00       0  0.0868  7.5736 │   3.171 │  0.98  -1.93
#   A5*:    72→74%   +1.3   1.47   1.59   3/8     93   1.88 0.012 │    -8.5   2.31     231  0.0290 15.0230 │   0.511 │  1.13  -1.99
#   A6 :    73→81%   +8.5   1.36   1.27   2/8     95   1.59 0.029 │    -7.8   2.33     233  0.0384  2.0423 │   0.324 │  0.91  -1.87
#   A7 :   91→100%   +9.3   0.33   0.33   1/8     93   0.36 0.042 │   -12.3   0.15      15 -0.1339  6.1093 │   0.000 │  1.11  -0.83
#   A8 :    90→93%   +3.5   0.56   0.27   0/8     99   0.27 0.001 │   -21.1   0.00       0 -0.0452 17.3622 │   0.000 │  1.07  -0.06
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1421 │ price 91→89 (peak 91)  cap=   17  TNAC=   29 │ sec= 88.8€ vol= 10.9 match=75% │ ent=0.0300  shp=1.000  eps=0.209 [ENT-DECAY] [cyc=A6]  │ warn: chron=3 bclust=2 hoard=5 1side=1 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→36%  +16.4   3.77   3.14   5/8     95   7.75 0.023 │    -9.9   6.73     673  0.1298 13.1718 │   5.280 │  1.01  -1.89
#   A2 :    22→46%  +24.3   3.54   3.09   0/8     94   4.80 0.036 │   -22.2   0.00       0 -0.0259  8.7866 │   4.869 │  0.98  -0.24
#   A3 :    42→45%   +2.1   2.84   3.23   0/8     97   4.48 0.014 │   -25.6   0.00       0  0.2579  1.7376 │   2.900 │  1.03  -0.51
#   A4 :    40→54%  +13.9   2.80   3.40   0/8     92   4.49 0.015 │   -23.4   0.00       0 -0.0285  2.7178 │   2.691 │  1.00  -0.73
#   A5 :    74→86%  +11.1   1.07   1.45   0/8    101   1.45 0.017 │   -20.7   0.00       0 -0.0661  1.1423 │   0.019 │  1.04  -2.01
#   A6*:    70→75%   +4.7   1.46   1.41   0/8     93   1.55 0.010 │   -16.9   0.00       0 -0.1152  9.2641 │   0.547 │  1.11  -1.07
#   A7 :   94→100%   +6.0   0.31   0.11   6/8     93   0.28 0.021 │     0.7   1.19     119 -0.1426  3.5848 │   0.000 │  1.13  -2.64
#   A8 :   91→100%   +9.1   0.41   0.22   3/8     89   0.24 0.033 │    -2.8   0.66      66  0.1166  5.1154 │   0.000 │  1.22  -1.99
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1470 │ price 54→86 (peak 95)  cap=   17  TNAC=   23 │ sec= 68.7€ vol= 23.2 match=88% │ ent=0.0300  shp=1.000  eps=0.208 [ENT-DECAY] [cyc=A7]  │ warn: cov<1=2 bclust=2 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→35%  +12.9   4.29   3.76   0/8     83   5.85 0.011 │   -10.5   0.00       0  0.1359  0.8288 │   3.300 │  0.93  -0.74
#   A2 :    20→43%  +23.2   4.28   3.49   0/8     81   4.81 0.028 │   -12.9   0.00       0  0.1151  1.2319 │   3.193 │  1.09  -0.80
#   A3 :    43→67%  +23.3   2.62   3.54   0/8     82   3.83 0.023 │   -21.9   0.00       0 -0.7091  5.4362 │   0.628 │  0.91  -0.99
#   A4 :    41→47%   +5.5   2.88   4.29   0/8     85   5.48 0.005 │   -21.8   0.00       0 -0.0461  2.7462 │   1.337 │  0.96  -2.08
#   A5 :    72→88%  +15.9   1.07   0.96   0/8     78   1.06 0.033 │   -20.0   0.00       0  0.0107  2.7306 │   0.000 │  1.13  -2.46
#   A6 :    70→84%  +13.6   1.24   1.17   0/8     75   1.47 0.013 │   -17.8   0.00       0 -0.2734  8.3737 │   0.000 │  1.06  -1.56
#   A7*:    91→97%   +6.1   0.48   0.25   0/8     79   0.27 0.020 │   -16.5   0.00       0  0.3618 12.2415 │   0.000 │  0.96  -1.48
#   A8 :   92→100%   +8.4   0.48   0.27   0/8     79   0.36 0.024 │   -16.7   0.00       0  0.2139 25.7612 │   0.000 │  1.11  -1.04
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Done — seed 42. Logs: results/training_log_s42.csv, results/year_log_s42.csv

# %% [markdown]
# ## 6. Analyze Training Results

# %%
# Load training logs
ep_df = pd.read_csv('results/training_log_s42.csv')
yr_df = pd.read_csv('results/year_log_s42.csv')

print(f'Training episodes: {len(ep_df)}')
print(f'Year-level records: {len(yr_df)}')
ep_df.tail()
# Out:
# Training episodes: 1500
# Year-level records: 8998
#       episode  clearing_price_last  cap_last  entropy_coef  shaping_weight  \
# 1495     1495            62.237930  17.20423          0.03             1.0
# 1496     1496            51.715927  17.20423          0.03             1.0
# 1497     1497            53.905277  17.20423          0.03             1.0
# 1498     1498            45.450306  17.20423          0.03             1.0
# 1499     1499            54.655373  17.20423          0.03             1.0
#
#       entropy_decay_triggered  active_agent  epsilon  reward_A1  \
# 1495                        1             7   0.2073   -13.9995
# 1496                        1             0   0.2073   -17.3685
# 1497                        1             1   0.2072   -15.0353
# 1498                        1             2   0.2072   -14.2138
# 1499                        1             3   0.2072   -11.5139
#
#       green_frac_A1  ...  total_cancels_A7  total_holding_cost_A7  \
# 1495         0.2513  ...                 0                 4.7682
# 1496         0.3400  ...                 0                 0.0000
# 1497         0.2940  ...                 0                 0.0003
# 1498         0.2853  ...                 0                 0.0000
# 1499         0.3022  ...                 0                64.8841
#
#       total_mac_reduction_A7  mean_alloc_A8  mean_shock_A8  max_shock_A8  \
# 1495                     0.0         0.2583            0.0           0.0
# 1496                     0.0         0.2769            0.0           0.0
# 1497                     0.0         0.3103            0.0           0.0
# 1498                     0.0         0.3123            0.0           0.0
# 1499                     0.0         0.3225            0.0           0.0
#
#       mean_cf_shock_A8  total_cancels_A8  total_holding_cost_A8  \
# 1495               0.0                 0                 7.0944
# 1496               0.0                 0                 0.5958
# 1497               0.0                 0               373.9451
# 1498               0.0                 0                 0.0354
# 1499               0.0                 0                 0.0000
#
#       total_mac_reduction_A8
# 1495                     0.0
# 1496                     0.0
# 1497                     0.0
# 1498                     0.0
# 1499                     0.0
#
# [5 rows x 142 columns]

# %%
# Plot training curves
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
n_agents = config['companies']['n_agents']
window = max(1, len(ep_df) // 50)  # smoothing window

# 1. Rewards
ax = axes[0, 0]
for i in range(n_agents):
    col = f'reward_A{i+1}'
    ax.plot(ep_df['episode'], ep_df[col].rolling(window).mean(), label=f'A{i+1}', alpha=0.8)
ax.set_xlabel('Episode')
ax.set_ylabel('Total Reward')
ax.set_title('Rewards (smoothed)')
ax.legend()
ax.grid(True, alpha=0.3)

# 2. Green fractions
ax = axes[0, 1]
for i in range(n_agents):
    col = f'green_frac_A{i+1}'
    ax.plot(ep_df['episode'], ep_df[col].rolling(window).mean() * 100, label=f'A{i+1}', alpha=0.8)
ax.set_xlabel('Episode')
ax.set_ylabel('Final Green (%)')
ax.set_title('Green Fraction at End of Episode')
ax.legend()
ax.grid(True, alpha=0.3)

# 3. Clearing price
ax = axes[1, 0]
ax.plot(ep_df['episode'], ep_df['clearing_price_last'].rolling(window).mean(), color='darkblue')
ax.set_xlabel('Episode')
ax.set_ylabel('€/t')
ax.set_title('Final Year Clearing Price')
ax.grid(True, alpha=0.3)

# 4. Actor loss
ax = axes[1, 1]
for i in range(n_agents):
    col = f'actor_loss_A{i+1}'
    ax.plot(ep_df['episode'], ep_df[col].rolling(window).mean(), label=f'A{i+1}', alpha=0.7)
ax.set_xlabel('Episode')
ax.set_ylabel('Loss')
ax.set_title('Actor Loss')
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Year-level analysis: last 50 episodes
last_eps = yr_df['episode'].unique()[-50:]
recent = yr_df[yr_df['episode'].isin(last_eps)]

fig, axes = plt.subplots(1, 3, figsize=(16, 4))

# Emissions by year (averaged over recent episodes)
ax = axes[0]
for i in range(n_agents):
    avg = recent.groupby('year')[f'emissions_A{i+1}'].mean()
    ax.plot(avg.index, avg.values, label=f'A{i+1}', marker='o', markersize=4)
ax.set_xlabel('Year')
ax.set_ylabel('Emissions (Mt)')
ax.set_title('Avg Emissions (last 50 episodes)')
ax.legend()
ax.grid(True, alpha=0.3)

# Green frac by year
ax = axes[1]
for i in range(n_agents):
    avg = recent.groupby('year')[f'green_frac_A{i+1}'].mean()
    ax.plot(avg.index, avg.values * 100, label=f'A{i+1}', marker='o', markersize=4)
ax.set_xlabel('Year')
ax.set_ylabel('Green (%)')
ax.set_title('Avg Green Fraction (last 50 episodes)')
ax.legend()
ax.grid(True, alpha=0.3)

# Carbon price trajectory
ax = axes[2]
avg_price = recent.groupby('year')['clearing_price'].mean()
avg_cap = recent.groupby('year')['cap'].mean()
ax.plot(avg_price.index, avg_price.values, label='Clearing Price', marker='^', color='blue')
ax2 = ax.twinx()
ax2.plot(avg_cap.index, avg_cap.values, label='Cap', marker='s', color='red', alpha=0.7)
ax.set_xlabel('Year')
ax.set_ylabel('Price (€/t)', color='blue')
ax2.set_ylabel('Cap (Mt)', color='red')
ax.set_title('Avg Price & Cap (last 50 episodes)')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6b. P5–P8 & MAC Stochastic Deviation Analysis
#
# Visualise the **random noise** and **abatement mechanisms** across training:
# - **P5** — Emission demand shocks (ε ~ correlated normal, σ=7%)
# - **P6** — Green capacity-factor noise + project cancellations
# - **P8** — Banking holding costs (penalty for excess allowance hoarding)
# - **MAC** — Fuel-switching abatement (coal→gas dispatch when carbon price > €65/t)

# %%
# ── P5/P6/P8 stochastic deviation analysis ─────────────────────────────────
yr_df = pd.read_csv('results/year_log_s42.csv')
n_agents = config['companies']['n_agents']
tech_names = config['technologies']['names']

# Check which deviation columns exist
shock_cols    = [f'emission_shock_A{i+1}' for i in range(n_agents)]
cf_cols       = [f'cf_shock_A{i+1}'       for i in range(n_agents)]
cancel_cols   = [f'cancellation_A{i+1}'   for i in range(n_agents)]
hcost_cols    = [f'holding_cost_A{i+1}'   for i in range(n_agents)]
mac_cols      = [f'mac_reduction_A{i+1}'  for i in range(n_agents)]

has_deviations = all(c in yr_df.columns for c in shock_cols)
has_mac = all(c in yr_df.columns for c in mac_cols)

cmap = plt.get_cmap('tab10')
agent_colors = [cmap(i % 10) for i in range(n_agents)]
leg_ncol = max(1, n_agents // 4)
bar_alpha = max(0.25, 0.55 - n_agents * 0.03)  # reduce opacity with more agents

if not has_deviations:
    print('Deviation columns not found — re-run training with the updated train.py')
else:
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))

    # ── 1. P5 emission shock distribution (all agents, all years) ────────────
    ax = axes[0, 0]
    for i in range(n_agents):
        vals = yr_df[shock_cols[i]] * 100
        ax.hist(vals, bins=40, alpha=bar_alpha, label=f'A{i+1}',
                density=True, color=agent_colors[i])
    ax.axvline(0, color='k', lw=1, ls='--')
    ax.set_xlabel('Emission shock ε (%)')
    ax.set_ylabel('Density')
    ax.set_title('P5 — Emission Demand Shocks\n(all years & episodes)')
    ax.legend(fontsize=7, ncol=leg_ncol)
    ax.grid(True, alpha=0.3)

    # ── 2. P5 shock correlation check (A1 vs A(n//2) — spread archetypes) ────
    ax = axes[0, 1]
    idx_a, idx_b = 0, max(1, n_agents // 2)
    ax.scatter(yr_df[shock_cols[idx_a]] * 100, yr_df[shock_cols[idx_b]] * 100,
               alpha=0.15, s=4, color='steelblue')
    lims = [-25, 25]
    ax.plot(lims, lims, 'k--', lw=0.8, label='1:1')
    ax.set_xlim(lims); ax.set_ylim(lims)
    ax.set_xlabel(f'A{idx_a+1} shock (%)')
    ax.set_ylabel(f'A{idx_b+1} shock (%)')
    corr = yr_df[shock_cols[idx_a]].corr(yr_df[shock_cols[idx_b]])
    ax.set_title(f'P5 — Cross-Agent Shock Correlation\nA{idx_a+1} vs A{idx_b+1}  (ρ_obs = {corr:.2f})')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

    # ── 3. MAC fuel-switching over training ──────────────────────────────────
    ax = axes[0, 2]
    if has_mac:
        ep_mac = (
            yr_df.groupby('episode')[[*mac_cols]]
            .sum()
            .rolling(50, min_periods=1)
            .mean()
        )
        for i in range(n_agents):
            ax.plot(ep_mac.index, ep_mac[mac_cols[i]],
                    label=f'A{i+1}', alpha=0.8, color=agent_colors[i])
        ax.set_xlabel('Episode')
        ax.set_ylabel('MAC abatement / episode (Mt)')
        ax.set_title('MAC Fuel-Switching over Training\n(50-ep rolling mean)')
        ax.legend(fontsize=7, ncol=leg_ncol)
    else:
        # Fallback: P5 shock volatility
        ep_shock_std = (
            yr_df.groupby('episode')[[*shock_cols]]
            .std()
            .rolling(50, min_periods=1)
            .mean()
        )
        for i in range(n_agents):
            ax.plot(ep_shock_std.index, ep_shock_std[shock_cols[i]] * 100,
                    label=f'A{i+1}', alpha=0.8, color=agent_colors[i])
        ax.axhline(7.0, color='k', ls='--', lw=0.8, label='σ_demand=7%')
        ax.set_xlabel('Episode')
        ax.set_ylabel('Within-episode shock std (%)')
        ax.set_title('P5 — Emission Shock Volatility over Training')
        ax.legend(fontsize=7, ncol=leg_ncol)
    ax.grid(True, alpha=0.3)

    # ── 4. P6 CF noise distribution (green techs averaged) ───────────────────
    ax = axes[1, 0]
    for i in range(n_agents):
        vals = yr_df[cf_cols[i]] * 100
        ax.hist(vals, bins=40, alpha=bar_alpha, label=f'A{i+1}',
                density=True, color=agent_colors[i])
    ax.axvline(0, color='k', lw=1, ls='--')
    ax.set_xlabel('Mean green CF noise (%)')
    ax.set_ylabel('Density')
    ax.set_title('P6 — Capacity-Factor Noise\n(mean across onshore/offshore/solar)')
    ax.legend(fontsize=7, ncol=leg_ncol)
    ax.grid(True, alpha=0.3)

    # ── 5. P6 project cancellations over training ─────────────────────────────
    ax = axes[1, 1]
    ep_cancels = (
        yr_df.groupby('episode')[[*cancel_cols]]
        .sum()
        .rolling(50, min_periods=1)
        .mean()
    )
    ep_cancels['total'] = ep_cancels[cancel_cols].sum(axis=1)
    ax.fill_between(ep_cancels.index, ep_cancels['total'],
                    alpha=0.3, color='coral', label='Total (all agents)')
    for i in range(n_agents):
        ax.plot(ep_cancels.index, ep_cancels[cancel_cols[i]],
                lw=0.8, label=f'A{i+1}', alpha=0.8, color=agent_colors[i])
    ax.set_xlabel('Episode')
    ax.set_ylabel('Avg cancellations / episode')
    ax.set_title('P6 — Project Cancellations over Training\n(50-ep rolling mean)')
    ax.legend(fontsize=7, ncol=leg_ncol)
    ax.grid(True, alpha=0.3)

    # ── 6. P8 holding cost over training ─────────────────────────────────────
    ax = axes[1, 2]
    has_hcost = all(c in yr_df.columns for c in hcost_cols)
    if has_hcost:
        ep_hcost = (
            yr_df.groupby('episode')[[*hcost_cols]]
            .sum()
            .rolling(50, min_periods=1)
            .mean()
        )
        for i in range(n_agents):
            ax.plot(ep_hcost.index, ep_hcost[hcost_cols[i]],
                    label=f'A{i+1}', alpha=0.8, color=agent_colors[i])
        ax.set_xlabel('Episode')
        ax.set_ylabel('Holding cost / episode (M€)')
        ax.set_title('P8 — Excess-Bank Holding Costs over Training\n(50-ep rolling mean)')
        ax.legend(fontsize=7, ncol=leg_ncol)
        ax.grid(True, alpha=0.3)
    else:
        ax.text(0.5, 0.5, 'holding_cost columns\nnot found in CSV',
                ha='center', va='center', transform=ax.transAxes)

    plt.suptitle('P5–P8 & MAC Stochastic Deviation Diagnostics', fontsize=14, y=1.01)
    plt.tight_layout()
    plt.show()

    # Summary statistics table
    print('\n─── P5/P6/P8/MAC deviation summary (all training data) ───')
    summary = {}
    for i in range(n_agents):
        row = {
            'ε_mean (%)':       round(yr_df[shock_cols[i]].mean()  * 100, 3),
            'ε_std (%)':        round(yr_df[shock_cols[i]].std()   * 100, 3),
            'CF_noise_std (%)': round(yr_df[cf_cols[i]].std()      * 100, 3),
            'cancels_total':    int(yr_df[cancel_cols[i]].sum()),
            'holdcost_sum (M€)': round(yr_df[hcost_cols[i]].sum(), 2) if has_hcost else 'n/a',
        }
        if has_mac:
            row['mac_total (Mt)'] = round(yr_df[mac_cols[i]].sum(), 2)
        summary[f'A{i+1}'] = row
    print(pd.DataFrame(summary).T.to_string())
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# ─── P5/P6/P8/MAC deviation summary (all training data) ───
#     ε_mean (%)  ε_std (%)  CF_noise_std (%)  cancels_total  holdcost_sum (M€)  mac_total (Mt)
# A1         0.0        0.0               0.0            0.0            5593.91         2194.37
# A2         0.0        0.0               0.0            0.0            3760.34         2193.93
# A3         0.0        0.0               0.0            0.0           46963.00          992.99
# A4         0.0        0.0               0.0            0.0           64117.89         1003.53
# A5         0.0        0.0               0.0            0.0           40704.56          144.85
# A6         0.0        0.0               0.0            0.0           60850.96          130.03
# A7         0.0        0.0               0.0            0.0          117302.04            0.00
# A8         0.0        0.0               0.0            0.0          143979.25            0.00

# %% [markdown]
# ## 6c. Year-by-Year Trajectory Analysis (last N episodes)
#
# Slices the **year_log** to show how behaviour evolves *within* an episode across years 0–9.
# Uses the last 100 episodes so the plots represent mature policy behaviour, not early exploration.
#
# Four panels per row:
# 1. **Allocation vs Emissions** — over-allocation → surplus banking; under-allocation → shortfall risk
# 2. **Banking** — bank_start and bank_end per year to see carry-forward dynamics
# 3. **Secondary market net** — positive = net seller (revenue), negative = net buyer (cost)
# 4. **Compliance surplus / shortfall** — pre-compliance headroom; negative → penalty risk

# %%
# ── 6c: Year-by-year trajectory analysis ──────────────────────────────────
yr_df = pd.read_csv('results/year_log_s42.csv')
n_agents = config['companies']['n_agents']

N_LAST = 100  # episodes to average over
last_eps = yr_df['episode'].unique()[-N_LAST:]
recent = yr_df[yr_df['episode'].isin(last_eps)].copy()

# Check which new columns are present
has_bank_end   = 'bank_end_A1'            in recent.columns
has_sec_net    = 'secondary_net_A1'       in recent.columns
has_surplus    = 'compliance_surplus_A1'  in recent.columns
has_auc_cost   = 'auction_cost_A1'        in recent.columns

cmap = plt.get_cmap('tab10')
agent_colors = [cmap(i) for i in range(n_agents)]

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# ── Panel 1: Allocation vs Emissions ──────────────────────────────────────
ax = axes[0, 0]
for i in range(n_agents):
    alloc_avg = recent.groupby('year')[f'alloc_A{i+1}'].mean()
    emiss_avg = recent.groupby('year')[f'emissions_A{i+1}'].mean()
    ax.plot(alloc_avg.index, alloc_avg.values,
            color=agent_colors[i], lw=2, label=f'A{i+1} alloc')
    ax.plot(emiss_avg.index, emiss_avg.values,
            color=agent_colors[i], lw=1.5, ls='--', alpha=0.7)
ax.set_xlabel('Year in Episode')
ax.set_ylabel('Mt CO₂')
ax.set_title(f'Allocation (solid) vs Emissions (dashed)\n(avg last {N_LAST} eps)')
ax.legend(fontsize=6, ncol=2)
ax.grid(True, alpha=0.3)

# ── Panel 2: Banking dynamics (bank_start and bank_end) ────────────────────
ax = axes[0, 1]
for i in range(n_agents):
    bs = recent.groupby('year')[f'bank_start_A{i+1}'].mean()
    ax.plot(bs.index, bs.values, color=agent_colors[i], lw=2,
            label=f'A{i+1}')
ax.axhline(0, color='k', lw=0.8, ls='--')
ax.set_xlabel('Year in Episode')
ax.set_ylabel('Banked Allowances (Mt)')
ax.set_title(f'Banking Dynamics (bank_start)\n(avg last {N_LAST} eps)')
ax.legend(fontsize=7, ncol=2)
ax.grid(True, alpha=0.3)

# ── Panel 3: Secondary market net (positive = net revenue) ────────────────
ax = axes[1, 0]
if has_sec_net:
    bar_width = 0.8 / n_agents
    for i in range(n_agents):
        avg = recent.groupby('year')[f'secondary_net_A{i+1}'].mean()
        ax.bar(avg.index + i * bar_width - 0.4 + bar_width/2, avg.values,
               width=bar_width, color=agent_colors[i], alpha=0.75, label=f'A{i+1}')
    ax.axhline(0, color='k', lw=0.8, ls='--')
    ax.set_xlabel('Year in Episode')
    ax.set_ylabel('Net secondary P&L (M€)  +ve=revenue')
    ax.set_title(f'Secondary Market Net Revenue by Year\n(avg last {N_LAST} eps)')
    ax.legend(fontsize=6, ncol=2)
else:
    for i in range(n_agents):
        avg = recent.groupby('year')[f'trade_cost_A{i+1}'].mean()
        ax.plot(avg.index, -avg.values, color=agent_colors[i], lw=1.5,
                label=f'A{i+1}', marker='o', markersize=3)
    ax.axhline(0, color='k', lw=0.8, ls='--')
    ax.set_xlabel('Year in Episode')
    ax.set_ylabel('−trade_cost (M€)  +ve=revenue')
    ax.set_title(f'Secondary Net (from trade_cost, last {N_LAST} eps)')
    ax.legend(fontsize=6, ncol=2)
ax.grid(True, alpha=0.3)

# ── Panel 4: Compliance surplus / shortfall ───────────────────────────────
ax = axes[1, 1]
if has_surplus:
    for i in range(n_agents):
        avg = recent.groupby('year')[f'compliance_surplus_A{i+1}'].mean()
        ax.plot(avg.index, avg.values, color=agent_colors[i], lw=2,
                marker='s', markersize=3, label=f'A{i+1}')
    ax.axhline(0, color='k', lw=1.2, ls='--', label='break-even')
else:
    for i in range(n_agents):
        sf = recent.groupby('year')[f'shortfall_A{i+1}'].mean()
        ax.plot(sf.index, -sf.values, color=agent_colors[i], lw=2,
                marker='s', markersize=3, label=f'A{i+1}')
    ax.axhline(0, color='k', lw=1.2, ls='--')
ax.set_xlabel('Year in Episode')
ax.set_ylabel('Surplus Mt  (+ve = safe, −ve = shortfall)')
ax.set_title(f'Compliance Surplus/Shortfall by Year\n(avg last {N_LAST} eps)')
ax.legend(fontsize=6, ncol=2)
ax.grid(True, alpha=0.3)

plt.suptitle(f'Year-by-Year Trajectory (last {N_LAST} episodes)', fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# ── Cost breakdown summary per year (if auction_cost logged) ──────────────
if has_auc_cost:
    print(f'\n── Average yearly cost breakdown (last {N_LAST} eps, all agents combined) ──')
    cols_show = {}
    for i in range(n_agents):
        cols_show[f'A{i+1}_auc(M€)'] = recent.groupby('year')[f'auction_cost_A{i+1}'].mean()
        cols_show[f'A{i+1}_inv(M€)'] = recent.groupby('year')[f'invest_cost_A{i+1}'].mean()
        cols_show[f'A{i+1}_pen(M€)'] = recent.groupby('year')[f'penalty_A{i+1}'].mean()
    print(pd.DataFrame(cols_show).round(2).to_string())
# Out:
# ── Average yearly cost breakdown (last 100 eps, all agents combined) ──
#       A1_auc(M€)  A1_inv(M€)  A1_pen(M€)  A2_auc(M€)  A2_inv(M€)  A2_pen(M€)  A3_auc(M€)  A3_inv(M€)  A3_pen(M€)  A4_auc(M€)  A4_inv(M€)  A4_pen(M€)  A5_auc(M€)  A5_inv(M€)  A5_pen(M€)  A6_auc(M€)  A6_inv(M€)  A6_pen(M€)  A7_auc(M€)  A7_inv(M€)  A7_pen(M€)  A8_auc(M€)  A8_inv(M€)  A8_pen(M€)
# year
# 0         250.44      107.12        1.54      230.93      147.91        0.02      264.24      116.01        0.00      267.13       84.28        1.08      125.45      122.42        0.21       70.54      115.79        1.73       14.97       99.71        0.77       18.44      100.67        0.68
# 1         208.05      270.06        9.92      217.86      276.28        1.11      263.75      148.60        0.97      269.07       96.81        0.00      111.28      125.35        0.56       88.85      190.36        2.86       19.32      124.47        7.81       19.31       73.42        5.51
# 2         231.06      162.96       22.28      230.80      191.58        2.96      231.95      128.91        1.57      258.61      100.13        0.31       91.48      137.21        1.28       67.62      205.86       10.89       17.78      106.27       14.54       16.39       90.54        9.29
# 3         234.78      164.44       39.87      219.62      184.49       22.95      233.12      123.39        0.00      226.28      154.41        0.12       85.58      175.55        0.78       57.81      176.22       17.14       19.97       83.90       12.56       15.94      102.08       11.55
# 4         236.93      159.12       55.76      214.67      171.10       24.83      193.22      168.48        1.02      205.49      137.00        0.00       89.46      143.36        0.46       66.28      179.28       13.35       15.48       74.43       15.28       14.42       91.80       11.87
# 5         239.39      136.66       79.85      224.68      141.94       36.18      203.62      160.03        0.00      202.31      171.99        1.30       79.08      145.71        0.55       54.54      181.02       16.31       15.77       56.52       14.67       15.72       62.68       13.80
# 6         237.06      154.76      100.72      225.52      147.48       40.17      184.43      170.96        2.95      206.90      153.68        1.32       73.92      171.00        0.59       55.17      160.18       19.44       15.11       41.27       12.87       13.78       46.26       10.72
# 7         221.71      130.94      106.95      213.47      140.37       53.91      175.31      209.98        1.11      201.75      195.23        4.98       67.37      130.13        2.43       45.49      139.82       20.26       12.83       19.57       10.87       12.26       34.98       10.96

# %% [markdown]
# ## 6d. Episode Consistency & Variance (ribbon plots)
#
# Shows **mean ± 1 std** bands over the last 100 episodes for key year-level signals.
# Wide bands → high variance / unstable policy. Narrow bands → consistent behaviour.
#
# Includes a **price ribbon** (year 0→9 trajectory) and per-agent **green fraction trajectory**.

# %%
# ── 6d: Episode consistency – ribbon plots (mean ± 1σ over last 100 episodes) ──
yr_df = pd.read_csv('results/year_log_s42.csv')
n_agents = config['companies']['n_agents']

N_LAST = 100
last_eps = yr_df['episode'].unique()[-N_LAST:]
recent = yr_df[yr_df['episode'].isin(last_eps)].copy()
years  = sorted(recent['year'].unique())

def ribbon(ax, grp, col, color, label):
    """Plot mean ± 1 std ribbon for `col` grouped by year."""
    mu  = grp[col].mean()
    std = grp[col].std().fillna(0)
    ax.plot(mu.index, mu.values, color=color, lw=2, label=label)
    ax.fill_between(mu.index, mu - std, mu + std,
                    color=color, alpha=0.18)

grp = recent.groupby('year')
# Use a colormap that handles 8+ agents
cmap = plt.get_cmap('tab10')
agent_colors = [cmap(i) for i in range(n_agents)]

fig, axes = plt.subplots(2, 3, figsize=(20, 10))

# ── 1. Clearing price trajectory ──────────────────────────────────────────
ax = axes[0, 0]
ribbon(ax, grp, 'clearing_price', 'steelblue', 'Clearing Price')
ax.set_xlabel('Year'); ax.set_ylabel('€/t')
ax.set_title('Clearing Price Trajectory\nmean ± 1σ (last 100 eps)')
ax.grid(True, alpha=0.3); ax.legend(fontsize=8)

# ── 2. Green fraction per agent ───────────────────────────────────────────
ax = axes[0, 1]
for i in range(n_agents):
    ribbon(ax, grp, f'green_frac_A{i+1}', agent_colors[i], f'A{i+1}')
ax.set_xlabel('Year'); ax.set_ylabel('Green fraction')
ax.set_title('Green Fraction Trajectory\nmean ± 1σ')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x*100:.0f}%'))
ax.grid(True, alpha=0.3); ax.legend(fontsize=7, ncol=2)

# ── 3. Emissions per agent ────────────────────────────────────────────────
ax = axes[0, 2]
for i in range(n_agents):
    ribbon(ax, grp, f'emissions_A{i+1}', agent_colors[i], f'A{i+1}')
ax.set_xlabel('Year'); ax.set_ylabel('Mt CO₂')
ax.set_title('Realized Emissions\nmean ± 1σ (P5 shock visible as wide bands)')
ax.grid(True, alpha=0.3); ax.legend(fontsize=7, ncol=2)

# ── 4. Banking (bank_start) per agent ─────────────────────────────────────
ax = axes[1, 0]
for i in range(n_agents):
    ribbon(ax, grp, f'bank_start_A{i+1}', agent_colors[i], f'A{i+1}')
ax.axhline(0, color='k', lw=0.8, ls='--')
ax.set_xlabel('Year'); ax.set_ylabel('Banked Mt')
ax.set_title('Banking Strategy\nmean ± 1σ')
ax.grid(True, alpha=0.3); ax.legend(fontsize=7, ncol=2)

# ── 5. Reward per agent ───────────────────────────────────────────────────
ax = axes[1, 1]
for i in range(n_agents):
    ribbon(ax, grp, f'reward_A{i+1}', agent_colors[i], f'A{i+1}')
ax.axhline(0, color='k', lw=0.8, ls='--')
ax.set_xlabel('Year'); ax.set_ylabel('Reward')
ax.set_title('Per-Year Reward\nmean ± 1σ')
ax.grid(True, alpha=0.3); ax.legend(fontsize=7, ncol=2)

# ── 6. P8 holding cost (if logged) / shortfall ────────────────────────────
ax = axes[1, 2]
has_hcost = 'holding_cost_A1' in recent.columns
if has_hcost:
    for i in range(n_agents):
        ribbon(ax, grp, f'holding_cost_A{i+1}', agent_colors[i], f'A{i+1} hold_cost')
    ax.set_ylabel('Holding cost M€')
    ax.set_title('P8 Holding Costs by Year\nmean ± 1σ')
else:
    for i in range(n_agents):
        ribbon(ax, grp, f'shortfall_A{i+1}', agent_colors[i], f'A{i+1}')
    ax.set_ylabel('Shortfall Mt')
    ax.set_title('Shortfall by Year\nmean ± 1σ')
ax.axhline(0, color='k', lw=0.8, ls='--')
ax.set_xlabel('Year'); ax.grid(True, alpha=0.3); ax.legend(fontsize=7, ncol=2)

plt.suptitle(f'Episode Consistency & Variance (last {N_LAST} episodes)', fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# ── Variance summary table ────────────────────────────────────────────────
print(f'\n── Year-level variance summary (std across {N_LAST} episodes, mean over years) ──')
var_summary = {}
for i in range(n_agents):
    var_summary[f'A{i+1}'] = {
        'price_std (€/t)':   round(recent.groupby('year')['clearing_price'].std().mean(), 2),
        'green_frac_std':    round(recent.groupby('year')[f'green_frac_A{i+1}'].std().mean(), 4),
        'emissions_std(Mt)': round(recent.groupby('year')[f'emissions_A{i+1}'].std().mean(), 3),
        'bank_std(Mt)':      round(recent.groupby('year')[f'bank_start_A{i+1}'].std().mean(), 3),
        'reward_std':        round(recent.groupby('year')[f'reward_A{i+1}'].std().mean(), 4),
    }
print(pd.DataFrame(var_summary).T.to_string())
# Out:
# ── Year-level variance summary (std across 100 episodes, mean over years) ──
#     price_std (€/t)  green_frac_std  emissions_std(Mt)  bank_std(Mt)  reward_std
# A1            15.87          0.0437              0.478         2.163      0.9247
# A2            15.87          0.0458              0.482         2.102      0.9390
# A3            15.87          0.0468              0.337         3.502      0.8372
# A4            15.87          0.0437              0.313         3.616      0.9035
# A5            15.87          0.0464              0.228         1.761      0.8603
# A6            15.87          0.0507              0.249         1.933      1.2369
# A7            15.87          0.0241              0.111         1.230      1.2225
# A8            15.87          0.0222              0.102         1.519      1.2269

# %% [markdown]
# ## 7. Evaluate Best Agents (Deterministic)

# %%
from scripts.train import build_agents

# Load best checkpoints
eval_env = ETSEnvironment(config, seed=0)
eval_agents = build_agents(eval_env, config, seed=0)
n_agents = config['companies']['n_agents']

ckpt_dir = 'results/checkpoints_s42'
for i, agent in enumerate(eval_agents):
    ckpt_path = os.path.join(ckpt_dir, f'agent_{i}_best.pt')
    if os.path.exists(ckpt_path):
        agent.load(ckpt_path)
        print(f'Loaded agent {i}')
    else:
        print(f'No checkpoint for agent {i} — using untrained policy')

# Run deterministic evaluation
obs1, _ = eval_env.reset(seed=0)
eval_data = []

for year in range(config['simulation']['n_years']):
    auction_actions = np.zeros((n_agents, 6), dtype=np.float32)
    for i in range(n_agents):
        action, _, _ = eval_agents[i].select_auction_action(obs1[i], deterministic=True)
        auction_actions[i] = action
    obs2, _ = eval_env.step_auction(auction_actions)

    secondary_actions = np.zeros((n_agents, 2), dtype=np.float32)
    for i in range(n_agents):
        action, _, _ = eval_agents[i].select_secondary_action(obs2[i], deterministic=True)
        secondary_actions[i] = action

    obs1, rewards, terminated, _, info = eval_env.step_secondary(secondary_actions)
    log = info['year_log']

    row = {'year': year, 'cap': log['cap'], 'price': log['clearing_price']}
    for i in range(n_agents):
        row[f'green_A{i+1}'] = log['green_fracs'][i]
        row[f'emissions_A{i+1}'] = log['emissions'][i]
        for t in range(5):
            row[f'mix_A{i+1}_{tech_names[t]}'] = log['tech_mixes'][i][t]
    eval_data.append(row)
    if terminated:
        break

eval_df = pd.DataFrame(eval_data)
green_cols = ['year', 'cap', 'price'] + [f'green_A{i+1}' for i in range(n_agents)]
print(eval_df[green_cols].to_string(index=False))
# Out:
# Loaded agent 0
# Loaded agent 1
# Loaded agent 2
# Loaded agent 3
# Loaded agent 4
# Loaded agent 5
# Loaded agent 6
# Loaded agent 7
#  year       cap      price  green_A1  green_A2  green_A3  green_A4  green_A5  green_A6  green_A7  green_A8
#     0 23.500000  71.909569  0.225409  0.222264  0.437506  0.439117  0.700000   0.71844  0.900000  0.900000
#     1 22.489500  90.471344  0.225409  0.229749  0.437506  0.439117  0.706040   0.71844  0.917404  0.900000
#     2 21.522451 114.733963  0.263430  0.229749  0.437506  0.439117  0.725303   0.74983  0.929845  0.925376
#     3 20.596986 111.656677  0.263430  0.229749  0.481162  0.456003  0.725303   0.74983  0.946198  0.959784
#     4 19.690719 120.000000  0.270529  0.239044  0.493940  0.456003  0.725303   0.74983  0.982590  0.969806
#     5 18.824327 120.000000  0.277393  0.239044  0.493940  0.456003  0.725303   0.74983  0.996888  0.978865
#     6 17.996057 120.000000  0.285699  0.239044  0.493940  0.456003  0.725303   0.74983  1.000000  0.987942
#     7 17.204230 120.000000  0.285699  0.239044  0.493940  0.457112  0.725303   0.74983  1.000000  0.996503
#     8 16.447244 120.000000  0.285699  0.244885  0.493940  0.465387  0.725303   0.74983  1.000000  1.000000
#     9 15.723565 120.000000  0.285699  0.244885  0.493940  0.476935  0.725303   0.74983  1.000000  1.000000
#    10 15.031728 120.000000  0.294151  0.250903  0.493940  0.476935  0.725303   0.74983  1.000000  1.000000
#    11 14.370332 120.000000  0.294151  0.250903  0.493940  0.484384  0.725303   0.74983  1.000000  1.000000

# %%
# Technology mix evolution per agent
tech_names = config['technologies']['names']
colors = {'coal': '#555555', 'gas': '#FF8C00', 'onshore_wind': '#2E8B57',
          'offshore_wind': '#1E90FF', 'solar': '#FFD700'}

# Dynamic archetype labels (2 of each for 8 agents)
_base_archetypes = ['Coal-Heavy', 'Gas-Dominant', 'Mixed', 'Near-Green']
archetypes = []
for arch in _base_archetypes:
    count = 0
    for mix in config['companies']['initial_mix']:
        # Match archetype by green fraction
        green = sum(mix[j] for j, g in enumerate(config['technologies']['is_green']) if g)
        if arch == 'Coal-Heavy' and green < 0.25:
            count += 1
        elif arch == 'Gas-Dominant' and 0.25 <= green < 0.55:
            count += 1
        elif arch == 'Mixed' and 0.55 <= green < 0.85:
            count += 1
        elif arch == 'Near-Green' and green >= 0.85:
            count += 1
# Simpler: just assign based on position
archetypes = []
n_per = n_agents // 4
for arch in _base_archetypes:
    for k in range(max(1, n_per)):
        archetypes.append(arch)
# Pad if needed
while len(archetypes) < n_agents:
    archetypes.append(f'Agent {len(archetypes)+1}')

ncols = min(4, n_agents)
nrows = (n_agents + ncols - 1) // ncols
fig, axes = plt.subplots(nrows, ncols, figsize=(5*ncols, 4*nrows), sharey=True)
axes = np.atleast_1d(axes).flatten()

for i in range(n_agents):
    ax = axes[i]
    bottom = np.zeros(len(eval_df))
    for t in range(5):
        vals = eval_df[f'mix_A{i+1}_{tech_names[t]}'].values * 100
        ax.bar(eval_df['year'], vals, bottom=bottom,
               label=tech_names[t].replace('_', ' ').title(),
               color=colors[tech_names[t]], alpha=0.85)
        bottom += vals
    ax.set_xlabel('Year')
    if i % ncols == 0:
        ax.set_ylabel('Mix (%)')
    ax.set_title(f'A{i+1}: {archetypes[i]}')
    ax.set_ylim(0, 100)

# Hide unused axes
for j in range(n_agents, len(axes)):
    axes[j].set_visible(False)

# Single legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=5, fontsize=9,
           bbox_to_anchor=(0.5, -0.02))

plt.suptitle('Technology Mix Evolution (Trained Policy)', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Investment Cost Sanity Check
#
# Verify that investment costs match real-world data (action plan §2).

# %%
env = ETSEnvironment(config, seed=42)
env.reset()
c = env.companies[0]  # A1: coal-heavy

print('=== Investment Cost Sanity Check ===')
print(f'Company output: {c.output_twh} TWh/year = {c.output_mwh/1e6:.0f} million MWh')
print()

for tech_idx, name in [(2, 'Onshore Wind'), (3, 'Offshore Wind'), (4, 'Solar PV')]:
    frac = 0.03  # 3% of output
    delta_mwh = frac * c.output_mwh
    cf = c.capacity_factors[tech_idx]
    delta_mw = delta_mwh / (cf * 8760)
    cost = c.compute_investment_cost(tech_idx, frac)
    print(f'{name}:')
    print(f'  Shift: {frac*100:.0f}% = {delta_mwh/1e6:.0f} GWh/yr')
    print(f'  New capacity: {delta_mw:.0f} MW (at CF={cf:.0%})')
    print(f'  CapEx: {c.capex[tech_idx]:.0f} €/kW')
    print(f'  Investment cost: {cost:.1f} M€')
    print()
# Out:
# === Investment Cost Sanity Check ===
# Company output: 10.0 TWh/year = 10 million MWh
#
# Onshore Wind:
#   Shift: 3% = 0 GWh/yr
#   New capacity: 98 MW (at CF=35%)
#   CapEx: 1350 €/kW
#   Investment cost: 132.7 M€
#
# Offshore Wind:
#   Shift: 3% = 0 GWh/yr
#   New capacity: 73 MW (at CF=47%)
#   CapEx: 3250 €/kW
#   Investment cost: 237.7 M€
#
# Solar PV:
#   Shift: 3% = 0 GWh/yr
#   New capacity: 201 MW (at CF=17%)
#   CapEx: 750 €/kW
#   Investment cost: 152.6 M€

# %% [markdown]
# ## 9. Full Training Run (Longer)
#
# Uncomment and run for a more complete training. Takes ~15-30 min on Colab GPU.

# %%
import copy
from scripts.train import train_one_seed

full_config = copy.deepcopy(config)

# Solo override logistici del run lungo
full_config['simulation']['n_episodes'] = 15000
full_config['logging']['log_interval'] = 97
full_config['logging']['results_dir'] = 'results/'

# IPPO
full_config['ppo']['centralized_critic'] = False

print("Full run config check")
print("entropy_coef       :", full_config['ppo']['entropy_coef'])
print("entropy_coef_final :", full_config['ppo']['entropy_coef_final'])
print("epsilon_start      :", full_config['exploration']['epsilon_start'])
print("epsilon_final      :", full_config['exploration']['epsilon_final'])
print("epsilon_decay_eps  :", full_config['exploration']['epsilon_decay_episodes'])
print("stuck_boost_window :", full_config['diagnostics']['stuck_boost_window'])
print("stuck_boost_coef   :", full_config['diagnostics']['stuck_boost_coef'])
print("price_markup_low   :", full_config['auction']['price_markup_low'])
print("price_markup_high  :", full_config['auction']['price_markup_high'])

train_one_seed(full_config, seed=42)
# Out:
# Full run config check
# entropy_coef       : 0.03
# entropy_coef_final : 0.02
# epsilon_start      : 0.25
# epsilon_final      : 0.05
# epsilon_decay_eps  : 7000
# stuck_boost_window : 250
# stuck_boost_coef   : 0.04
# price_markup_low   : 0.9
# price_markup_high  : 1.25
#
# ============================================================
# Training — seed 42, 8 agents, IPPO (independent critic), two-phase
# v5.0: MAC switching | Electricity revenue | Carry-forward | CF-cap=0.5×
# Clipped Gaussian (no tanh) + P1-P8 active | Curriculum 4→12yr | ε-greedy 25%→5%
# ============================================================
#
# ──────────────────────────────────────────────────────────────────────────────────
# TRAINING CONSOLE — COLUMN GUIDE
# ──────────────────────────────────────────────────────────────────────────────────
# Market header  (printed every log_interval episodes)
#   price X→Y (peak Z) : ETS clearing price yr-0 → yr-N and peak  (€/t)
#   cap                : Cap (Mt) in the final year
#   TNAC               : Total allowances in circulation, final year
#   sec_price/vol/match: Secondary market stats
#   entropy/shaping    : PPO entropy coef & green-shaping weight
#   [ENT-DECAY]        : Entropy decay triggered
#   [cyc=Ax]           : Active agent (soft cycling)
#
# Per-agent columns
#   Green(0→N)  : Green fraction trajectory
#   ΔGreen      : Net green change (pp)
#   AvgEmiss    : Mean emissions (Mt)
#   AvgAlloc    : Mean allocation (Mt)
#   SfYrs       : Shortfall years
#   AvgBid€     : Mean bid price (€/t)
#   BidMt       : Mean bid volume (Mt) — after coverage-multiplier expansion
#   InvFr       : Mean invest_frac action (how aggressively agent invests)
#   TotRew      : Total raw reward
#   TotShort    : Total shortfall (Mt)
#   TotPenalty  : Total penalty (M€)
#   ActLoss     : Actor loss
#   CriLoss     : Critic loss
#   MAC_Mt      : MAC fuel-switching reduction (Mt)
#   SecMl       : Mean secondary price multiplier (action[0]; 0.5=discount 2.0=premium)
#   SqAct       : Mean secondary qty action (+buy intent / -sell intent, Mt)
# ──────────────────────────────────────────────────────────────────────────────────
#
# ────────────────────────────────────────────────────────────
# Behavioral cloning pre-training
#   Episodes: 300  |  Epochs: 10  |  LR: 0.001
#   Policies: AuctionPolicy + SecondaryPolicy
# ────────────────────────────────────────────────────────────
#   A1 [auction]    epoch  1/10  loss=0.3222
#   A1 [auction]    epoch 10/10  loss=0.0336
#   A1 [secondary]  epoch  1/10  loss=0.1005
#   A1 [secondary]  epoch 10/10  loss=0.0252
#   A2 [auction]    epoch  1/10  loss=0.3155
#   A2 [auction]    epoch 10/10  loss=0.0343
#   A2 [secondary]  epoch  1/10  loss=0.1001
#   A2 [secondary]  epoch 10/10  loss=0.0202
#   A3 [auction]    epoch  1/10  loss=0.2754
#   A3 [auction]    epoch 10/10  loss=0.0380
#   A3 [secondary]  epoch  1/10  loss=0.0633
#   A3 [secondary]  epoch 10/10  loss=0.0029
#   A4 [auction]    epoch  1/10  loss=0.2714
#   A4 [auction]    epoch 10/10  loss=0.0390
#   A4 [secondary]  epoch  1/10  loss=0.0650
#   A4 [secondary]  epoch 10/10  loss=0.0025
#   A5 [auction]    epoch  1/10  loss=0.3107
#   A5 [auction]    epoch 10/10  loss=0.0373
#   A5 [secondary]  epoch  1/10  loss=0.0440
#   A5 [secondary]  epoch 10/10  loss=0.0051
#   A6 [auction]    epoch  1/10  loss=0.2905
#   A6 [auction]    epoch 10/10  loss=0.0302
#   A6 [secondary]  epoch  1/10  loss=0.0388
#   A6 [secondary]  epoch 10/10  loss=0.0045
#   A7 [auction]    epoch  1/10  loss=0.2834
#   A7 [auction]    epoch 10/10  loss=0.0361
#   A7 [secondary]  epoch  1/10  loss=0.0349
#   A7 [secondary]  epoch 10/10  loss=0.0076
#   A8 [auction]    epoch  1/10  loss=0.2757
#   A8 [auction]    epoch 10/10  loss=0.0295
#   A8 [secondary]  epoch  1/10  loss=0.0366
#   A8 [secondary]  epoch 10/10  loss=0.0078
# ────────────────────────────────────────────────────────────
# Behavioral cloning pre-training complete.
#
# KL anchor: frozen BC policies captured for all 8 agents (β₀=0.5, decay=5000 eps).
# Critic-warmup: actor gradients frozen for first 100 episodes.
# Curriculum: 4yr → 12yr over 3000 episodes.
# Epsilon-greedy: 0.25 → 0.05 over 7000 episodes (physical-space).
# Epsilon-greedy: 0.25 → 0.05 over 7000 episodes (physical-space).
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep     0 │ price 45→60 (peak 60)  cap=   21  TNAC=   20 │ sec= 59.7€ vol=  9.9 match=100% │ ent=0.0300  shp=1.000  eps=0.250 [ENT-DECAY] [cyc=A1] [WARMUP 1/100]  │ warn: bclust=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1*:    25→31%   +6.4   4.69   4.88   0/4     58   7.73 0.017 │    -7.1   0.00       0  0.0000  1.7001 │   0.000 │  0.91  -0.47
#   A2 :    23→33%   +9.8   4.67   4.53   0/4     58   6.30 0.030 │    -8.8   0.00       0  0.0000  1.6737 │   0.000 │  0.97   0.24
#   A3 :    42→53%  +11.0   3.04   2.89   0/4     62   3.07 0.027 │    -7.4   0.00       0  0.0000  3.0540 │   0.000 │  1.24   0.56
#   A4 :    44→49%   +4.8   2.94   3.16   0/4     57   3.54 0.033 │    -7.1   0.00       0  0.0000  2.3826 │   0.000 │  1.05  -0.76
#   A5 :    70→73%   +2.9   1.63   0.76   1/4     57   1.42 0.006 │    -0.2   0.81      81  0.0000  1.3569 │   0.000 │  0.95   0.21
#   A6 :    70→71%   +1.4   1.72   2.10   0/4     55   2.27 0.035 │    -6.9   0.00       0  0.0000  0.8936 │   0.000 │  1.15  -1.03
#   A7 :    92→95%   +2.6   0.53   0.36   2/4     52   0.50 0.029 │    -0.4   0.43      43  0.0000  9.8976 │   0.000 │  1.06  -0.36
#   A8 :    91→96%   +4.9   0.53   0.56   0/4     60   0.56 0.027 │    -6.1   0.00       0  0.0000  5.5176 │   0.000 │  1.04  -1.57
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep    97 │ price 68→56 (peak 68)  cap=   21  TNAC=   25 │ sec= 70.1€ vol=  8.9 match=100% │ ent=0.0300  shp=1.000  eps=0.247 [ENT-DECAY] [cyc=A2] [WARMUP 98/100]  │ warn: bclust=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→22%   +0.0   4.93   4.27   0/4     67   7.55 0.028 │    -8.6   0.00       0  0.0000  1.0796 │   0.660 │  1.07  -0.09
#   A2*:    22→22%   +0.0   4.97   3.65   2/4     70  10.61 0.021 │    -4.9   3.36     336  0.0000  5.3073 │   0.660 │  1.13   0.35
#   A3 :    41→47%   +5.1   3.13   3.73   0/4     69   4.16 0.034 │   -10.2   0.00       0  0.0000  3.1124 │   0.447 │  1.18   0.90
#   A4 :    45→54%   +8.3   2.82   3.12   0/4     67   3.44 0.045 │    -8.6   0.00       0  0.0000  0.9344 │   0.316 │  1.08  -0.54
#   A5 :    71→75%   +4.0   1.55   1.56   0/4     71   1.69 0.020 │    -5.8   0.00       0  0.0000  0.9966 │   0.136 │  1.07   0.10
#   A6 :    71→79%   +8.0   1.29   0.91   0/4     64   1.76 0.027 │    -8.6   0.00       0  0.0000  2.0017 │   0.131 │  1.10   0.54
#   A7 :   90→100%  +10.0   0.46   0.30   1/4     62   0.41 0.044 │    -0.5   0.18      18  0.0000 14.0259 │   0.000 │  0.98  -1.19
#   A8 :    90→99%   +8.6   0.49   0.60   1/4     67   0.75 0.048 │    -4.2   0.46      46  0.0000  1.6081 │   0.000 │  1.03   0.74
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   194 │ price 65→49 (peak 65)  cap=   20  TNAC=   17 │ sec= 41.7€ vol= 17.3 match=100% │ ent=0.0300  shp=1.000  eps=0.244 [ENT-DECAY] [cyc=A3]
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→30%  +10.2   4.73   4.85   0/5     71   6.71 0.028 │    -2.9   0.00       0  0.0024  8.2483 │   0.000 │  0.95  -1.39
#   A2 :    20→26%   +6.4   4.91   3.88   1/5     63   6.85 0.051 │    -4.2   1.57     157 -0.0022 12.2069 │   0.000 │  1.11  -1.47
#   A3*:    41→49%   +8.1   3.08   3.81   0/5     67   4.87 0.029 │    -7.3   0.00       0 -0.0053  3.4420 │   0.000 │  1.00  -0.93
#   A4 :    40→49%   +9.5   3.07   2.82   0/5     66   3.14 0.033 │    -7.2   0.00       0 -0.0094  1.4016 │   0.000 │  0.96  -0.45
#   A5 :    72→77%   +4.4   1.45   2.08   0/5     68   2.08 0.036 │   -10.3   0.00       0 -0.0040  8.3563 │   0.000 │  0.96  -0.99
#   A6 :    70→73%   +3.1   1.63   1.33   0/5     66   1.76 0.027 │    -7.0   0.00       0 -0.0069  0.6628 │   0.000 │  1.07  -0.97
#   A7 :    91→95%   +4.1   0.51   0.65   0/5     69   0.65 0.032 │   -11.5   0.00       0 -0.0082  2.8613 │   0.000 │  1.08  -0.47
#   A8 :   91→100%   +9.5   0.48   0.42   0/5     68   0.52 0.043 │    -6.5   0.00       0 -0.0023  0.3035 │   0.000 │  1.03  -0.76
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   291 │ price 77→50 (peak 77)  cap=   20  TNAC=   24 │ sec= 53.0€ vol= 17.1 match=100% │ ent=0.0300  shp=1.000  eps=0.242 [ENT-DECAY] [cyc=A4]  │ warn: bclust=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    21→27%   +6.6   4.42   3.53   1/5     78   5.47 0.028 │    -5.3   1.47     147 -0.0056  1.7955 │   1.980 │  1.02   1.33
#   A2 :    22→26%   +4.5   4.53   4.03   0/5     77   6.78 0.025 │   -11.0   0.00       0 -0.0076  1.2001 │   1.980 │  1.10  -1.66
#   A3 :    42→46%   +3.3   2.93   3.57   0/5     82   4.03 0.024 │   -12.7   0.00       0 -0.0040  1.5779 │   1.066 │  0.98  -0.80
#   A4*:    40→59%  +19.2   2.51   2.24   0/5     75   2.24 0.040 │    -6.6   0.00       0 -0.0514  3.8256 │   0.913 │  0.97  -0.88
#   A5 :    72→74%   +1.6   1.47   1.71   0/5     74   1.71 0.030 │    -7.6   0.00       0 -0.0089  4.0621 │   0.220 │  0.93  -1.79
#   A6 :    71→79%   +8.0   1.39   1.27   1/5     82   1.27 0.028 │    -1.6   0.53      53 -0.0162  4.1242 │   0.322 │  0.96  -0.53
#   A7 :   94→100%   +6.0   0.37   0.42   0/5     78   0.42 0.046 │   -10.9   0.00       0 -0.0060  3.2897 │   0.000 │  1.01  -0.13
#   A8 :   90→100%  +10.0   0.35   0.28   0/5     78   0.28 0.041 │    -9.5   0.00       0 -0.0263  1.0558 │   0.000 │  1.01   1.16
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   388 │ price 56→49 (peak 56)  cap=   20  TNAC=   18 │ sec= 41.9€ vol= 11.4 match=100% │ ent=0.0300  shp=1.000  eps=0.239 [ENT-DECAY] [cyc=A5]  │ warn: chron=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→38%  +18.5   4.64   3.99   0/5     60   6.04 0.018 │    -8.8   0.00       0 -0.0285  5.4495 │   0.000 │  0.99  -2.04
#   A2 :    23→39%  +16.2   4.67   3.34   0/5     53   6.93 0.042 │    -9.7   0.00       0  0.0028  0.8334 │   0.000 │  0.94   0.59
#   A3 :    42→45%   +3.1   3.21   3.78   0/5     63   4.38 0.018 │    -9.2   0.00       0 -0.0283  3.8213 │   0.000 │  0.90  -1.81
#   A4 :    41→43%   +1.7   3.36   3.45   1/5     61   4.14 0.020 │    -5.6   0.19      19 -0.0119  1.8725 │   0.000 │  0.87  -2.33
#   A5*:    72→74%   +2.1   1.46   1.48   0/5     61   1.48 0.013 │   -14.7   0.00       0  0.0011  8.8204 │   0.000 │  1.03  -0.79
#   A6 :    73→86%  +12.8   1.02   0.72   0/5     54   1.04 0.034 │   -13.1   0.00       0 -0.0096  5.4933 │   0.000 │  1.01   0.47
#   A7 :    90→95%   +5.0   0.55   0.32   3/5     61   0.44 0.014 │    -1.5   0.79      79 -0.0056 16.5575 │   0.000 │  1.10  -1.87
#   A8 :   92→100%   +7.5   0.45   0.43   0/5     59   0.43 0.040 │   -11.7   0.00       0 -0.0075  4.1847 │   0.000 │  1.06  -2.25
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   485 │ price 78→91 (peak 91)  cap=   20  TNAC=   28 │ sec= 88.3€ vol= 13.7 match=80% │ ent=0.0300  shp=1.000  eps=0.236 [ENT-DECAY] [cyc=A6]  │ warn: bclust=2 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→31%  +11.0   4.11   3.96   0/5     87   6.24 0.031 │   -16.1   0.00       0 -0.0074 10.7498 │   3.300 │  1.00  -0.63
#   A2 :    20→23%   +3.5   4.46   4.35   0/5     97   6.68 0.030 │   -13.9   0.00       0 -0.0158  2.1147 │   3.300 │  1.01  -1.44
#   A3 :    40→52%  +11.7   2.81   2.97   2/5     87   3.68 0.053 │    -4.5   0.95      95 -0.0422  5.3311 │   1.701 │  0.92  -1.95
#   A4 :    42→46%   +3.9   2.83   3.30   0/5     88   3.67 0.028 │   -15.0   0.00       0  0.0148  7.3432 │   1.793 │  1.06  -2.05
#   A5 :    70→76%   +6.1   1.40   1.13   0/5     92   1.44 0.011 │   -10.8   0.00       0 -0.0169  3.9871 │   0.168 │  0.90  -0.96
#   A6*:    70→76%   +5.5   1.42   0.87   2/5     97   0.87 0.000 │    -4.8   2.01     201  0.0025  4.3253 │   0.203 │  0.98  -1.04
#   A7 :   91→100%   +9.0   0.41   0.32   0/5     95   0.32 0.016 │   -10.3   0.00       0  0.0063  0.2712 │   0.000 │  1.20  -1.67
#   A8 :    93→99%   +5.6   0.46   0.17   0/5     91   0.22 0.012 │   -12.0   0.00       0 -0.0218  4.3883 │   0.000 │  1.08  -0.20
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   582 │ price 57→62 (peak 69)  cap=   19  TNAC=   21 │ sec= 64.7€ vol= 16.8 match=83% │ ent=0.0300  shp=1.000  eps=0.233 [ENT-DECAY] [cyc=A7]  │ warn: bclust=1 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→29%   +6.8   4.54   3.94   2/6     68   6.77 0.014 │    -9.8   0.87      87 -0.0138  2.9285 │   0.660 │  0.99  -2.81
#   A2 :    20→26%   +6.4   4.96   3.69   0/6     64   8.14 0.008 │   -13.8   0.00       0 -0.0368  1.8208 │   0.660 │  1.17  -1.63
#   A3 :    44→47%   +3.1   2.97   3.27   0/6     66   4.64 0.009 │   -13.8   0.00       0 -0.0054  1.8988 │   0.250 │  0.97  -1.39
#   A4 :    41→41%   +0.0   3.35   3.02   0/6     65   5.05 0.024 │   -18.6   0.00       0 -0.0425 10.6440 │   0.456 │  1.06  -1.33
#   A5 :    70→75%   +5.3   1.61   1.51   1/6     64   1.85 0.037 │   -11.7   0.10      10 -0.0307  6.4786 │   0.135 │  0.91  -2.29
#   A6 :    74→77%   +3.2   1.35   0.86   0/6     68   0.99 0.007 │   -14.2   0.00       0  0.0098  7.7476 │   0.000 │  0.92  -1.04
#   A7*:    91→98%   +7.3   0.39   0.21   1/6     66   0.28 0.037 │    -5.5   0.06       6 -0.0531  2.6864 │   0.000 │  1.24  -1.57
#   A8 :    92→92%   +0.7   0.59   0.31   1/6     70   0.31 0.016 │    -9.5   0.27      27 -0.0332  0.4974 │   0.000 │  1.19  -1.43
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   679 │ price 62→50 (peak 62)  cap=   19  TNAC=   20 │ sec= 46.0€ vol= 14.2 match=100% │ ent=0.0300  shp=1.000  eps=0.231 [ENT-DECAY] [cyc=A8]  │ warn: cov<1=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→26%   +5.7   4.99   4.18   0/6     57   6.56 0.021 │   -17.3   0.00       0 -0.0287  1.1161 │   0.000 │  0.94  -0.02
#   A2 :    21→30%   +8.6   4.72   4.03   0/6     62   4.92 0.029 │   -18.2   0.00       0  0.0039  1.3852 │   0.000 │  1.21  -0.79
#   A3 :    40→46%   +5.9   3.21   3.86   0/6     59   4.75 0.023 │   -14.7   0.00       0 -0.0239  2.3997 │   0.000 │  0.98  -0.65
#   A4 :    40→50%  +10.5   2.89   2.59   3/6     61   3.28 0.049 │    -3.6   4.00     400 -0.0201  6.1710 │   0.000 │  0.84  -3.00
#   A5 :    71→79%   +7.7   1.36   0.96   1/6     63   0.96 0.011 │    -6.0   0.02       2 -0.0065  3.3106 │   0.000 │  0.94  -1.26
#   A6 :    71→90%  +19.4   0.98   0.83   2/6     64   0.83 0.040 │    -9.1   0.70      70 -0.0286  3.0417 │   0.000 │  0.96  -1.27
#   A7 :   91→100%   +8.6   0.31   0.23   1/6     63   0.23 0.024 │    -4.8   0.09       9 -0.0464  5.0089 │   0.000 │  1.15  -2.51
#   A8*:   91→100%   +9.0   0.32   0.06   2/6     59   0.26 0.036 │    -3.0   0.52      52  0.0455  9.1053 │   0.000 │  1.11  -1.18
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   776 │ price 63→84 (peak 84)  cap=   19  TNAC=   25 │ sec= 83.6€ vol=  8.5 match=67% │ ent=0.0300  shp=1.000  eps=0.228 [ENT-DECAY] [cyc=A1]  │ warn: chron=2 bclust=3 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1*:    21→26%   +4.8   4.42   4.31   0/6     90   9.97 0.014 │   -11.0   0.00       0 -0.0865  4.0940 │   3.300 │  0.95  -1.71
#   A2 :    23→28%   +5.5   4.18   4.30   0/6     84   8.01 0.022 │   -18.4   0.00       0 -0.0342  1.6450 │   3.300 │  1.08  -2.79
#   A3 :    46→48%   +2.3   2.73   3.21   0/6     85   3.63 0.015 │   -19.2   0.00       0 -0.0398  5.0699 │   1.129 │  0.95  -1.41
#   A4 :    42→47%   +4.8   2.87   2.11   5/6     87   2.19 0.015 │    -4.1   6.72     672 -0.0417  4.3067 │   1.596 │  0.87  -2.48
#   A5 :    70→74%   +3.6   1.50   1.32   0/6     83   1.79 0.057 │   -18.0   0.00       0 -0.0066 15.1893 │   0.270 │  0.86  -1.21
#   A6 :    71→84%  +12.5   1.33   1.24   3/6     85   1.49 0.035 │    -2.2   2.54     254 -0.0165  5.5717 │   0.000 │  0.86  -1.67
#   A7 :    91→96%   +5.1   0.46   0.19   2/6     88   0.33 0.020 │    -1.6   0.50      50 -0.0379 16.1893 │   0.000 │  1.24  -2.87
#   A8 :    92→95%   +2.5   0.48   0.19   3/6     91   0.19 0.000 │    -4.8   1.15     115 -0.0353  2.0124 │   0.000 │  1.20  -2.19
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   873 │ price 75→51 (peak 75)  cap=   19  TNAC=   24 │ sec= 50.8€ vol=  8.7 match=67% │ ent=0.0300  shp=1.000  eps=0.225 [ENT-DECAY] [cyc=A2]  │ warn: chron=3 1side=1 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    26→29%   +3.1   4.29   3.96   0/6     77   7.45 0.002 │   -15.3   0.00       0 -0.0192  1.0309 │   1.980 │  0.91  -1.53
#   A2*:    24→26%   +2.5   4.48   4.02   0/6     72   8.42 0.013 │   -18.5   0.00       0 -0.0393  2.8653 │   1.980 │  1.18  -1.54
#   A3 :    42→44%   +1.6   3.05   3.16   0/6     71   4.45 0.033 │   -19.1   0.00       0 -0.0181  2.9737 │   1.173 │  1.05  -1.46
#   A4 :    42→48%   +5.7   2.95   3.09   0/6     68   3.46 0.022 │   -17.6   0.00       0 -0.0041  6.2871 │   1.107 │  1.00  -1.14
#   A5 :    75→77%   +2.0   1.32   0.56   3/6     75   0.79 0.013 │    -4.6   2.75     275  0.0100  2.1744 │   0.007 │  1.03  -1.09
#   A6 :    72→83%  +11.1   1.17   0.74   5/6     68   1.20 0.039 │    -1.0   2.86     286 -0.0062  8.6082 │   0.092 │  0.93  -1.24
#   A7 :   90→100%  +10.0   0.61   0.23   2/6     73   0.40 0.026 │   -10.1   0.81      81 -0.0487  7.6274 │   0.000 │  1.21  -1.60
#   A8 :    90→98%   +8.1   0.46   0.26   5/6     67   0.42 0.020 │     2.3   1.95     195 -0.0202 24.1849 │   0.000 │  1.21  -2.49
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep   970 │ price 44→54 (peak 55)  cap=   18  TNAC=   19 │ sec= 52.9€ vol=  5.5 match=57% │ ent=0.0300  shp=1.000  eps=0.222 [ENT-DECAY] [cyc=A3]  │ warn: cov<1=1 chron=3 bclust=4 1side=3 0vol=3
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→39%  +16.6   4.64   3.73   1/7     56   6.66 0.036 │    -9.5   2.03     203 -0.0172  8.2255 │   0.000 │  0.89  -2.62
#   A2 :    25→34%   +9.1   4.75   3.69   4/7     56   6.07 0.034 │   -10.3  11.41    1141  0.0317  8.0276 │   0.000 │  1.27  -2.02
#   A3*:    43→45%   +1.6   3.23   3.93   0/7     57   4.52 0.026 │   -22.3   0.00       0 -0.3774  2.4335 │   0.000 │  1.06  -0.14
#   A4 :    40→43%   +3.3   3.31   3.26   0/7     58   3.54 0.045 │   -21.5   0.00       0 -0.3837  7.2838 │   0.000 │  0.93  -1.17
#   A5 :    74→79%   +5.3   1.30   1.11   2/7     61   1.12 0.009 │    -9.7   0.75      75 -0.5752  1.0579 │   0.000 │  0.92  -3.00
#   A6 :    72→78%   +6.2   1.35   0.57   2/7     63   0.57 0.000 │   -10.4   1.03     103 -0.3326  2.9416 │   0.000 │  0.93  -1.90
#   A7 :    91→99%   +8.4   0.53   0.33   3/7     60   0.35 0.009 │    -1.9   0.60      60  0.0339 30.7181 │   0.000 │  1.09  -1.79
#   A8 :   91→100%   +9.4   0.43   0.31   7/7     55   0.31 0.052 │     1.1   1.50     150  0.2144  7.3856 │   0.000 │  1.21  -2.19
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1067 │ price 78→77 (peak 88)  cap=   18  TNAC=   23 │ sec= 69.4€ vol= 14.4 match=71% │ ent=0.0300  shp=1.000  eps=0.220 [ENT-DECAY] [cyc=A4]  │ warn: chron=1 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→27%   +7.3   4.28   3.83   0/7     91   7.71 0.019 │   -19.6   0.00       0 -0.4186  5.5973 │   4.620 │  0.94  -1.61
#   A2 :    22→32%   +9.6   3.91   3.93   0/7     90   6.00 0.042 │   -23.1   0.00       0  0.3453 21.9993 │   4.620 │  1.08  -1.64
#   A3 :    40→62%  +21.8   2.57   3.83   0/7     92   4.14 0.033 │   -17.3   0.00       0 -0.5877  2.5767 │   1.639 │  0.83  -3.00
#   A4*:    42→44%   +1.4   2.88   2.95   1/7     96   3.26 0.012 │   -12.7   0.01       1  1.5191  3.9274 │   2.721 │  0.91  -2.05
#   A5 :    71→80%   +9.2   1.31   1.17   0/7     95   1.17 0.005 │   -10.8   0.00       0  0.3300  0.3016 │   0.277 │  0.95  -2.67
#   A6 :    73→81%   +8.8   1.31   0.90   4/7     94   1.23 0.008 │    -4.7   4.13     413  0.0920  5.2973 │   0.089 │  0.86  -1.79
#   A7 :   91→100%   +9.0   0.46   0.21   1/7     92   0.31 0.027 │   -15.2   0.07       7 -0.5136 12.5734 │   0.000 │  1.07   0.47
#   A8 :    91→95%   +4.0   0.51   0.29   0/7     93   0.33 0.025 │   -11.9   0.00       0  0.3083  4.2720 │   0.000 │  1.18  -2.29
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1164 │ price 63→71 (peak 78)  cap=   18  TNAC=   23 │ sec= 78.3€ vol= 19.8 match=100% │ ent=0.0300  shp=1.000  eps=0.217 [ENT-DECAY] [cyc=A5]  │ warn: bclust=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→27%   +7.0   4.56   4.16   1/7     81   9.72 0.001 │    -7.8   0.13      13 -0.8458 14.0865 │   1.980 │  0.90  -1.59
#   A2 :    25→33%   +7.4   4.20   3.32   0/7     74   7.13 0.042 │   -16.7   0.00       0  0.3083  2.1440 │   1.980 │  1.10  -0.15
#   A3 :    44→58%  +14.0   2.63   3.77   0/7     78   3.97 0.020 │    -6.6   0.00       0  0.4737 11.3209 │   0.037 │  0.85  -1.38
#   A4 :    41→52%  +10.8   2.95   3.03   0/7     77   4.49 0.021 │   -11.2   0.00       0  0.5943  3.2201 │   0.527 │  0.89  -2.89
#   A5*:    71→78%   +7.5   1.32   1.27   0/7     82   1.27 0.006 │   -14.4   0.00       0  0.0627  4.4159 │   0.000 │  0.99  -2.21
#   A6 :    71→83%  +12.3   1.33   1.26   1/7     75   1.32 0.022 │    -8.3   0.00       0 -0.3000  4.1504 │   0.000 │  0.98  -1.74
#   A7 :   90→100%   +9.9   0.50   0.25   0/7     69   0.41 0.032 │   -18.2   0.00       0  0.1168 17.0847 │   0.000 │  1.11   1.73
#   A8 :   90→100%  +10.0   0.46   0.25   0/7     70   0.41 0.055 │   -19.2   0.00       0 -0.2510 15.7960 │   0.000 │  1.15   0.97
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1261 │ price 73→63 (peak 89)  cap=   18  TNAC=   23 │ sec= 73.1€ vol= 16.2 match=71% │ ent=0.0300  shp=1.000  eps=0.214 [ENT-DECAY] [cyc=A6]  │ warn: chron=1 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→35%  +14.8   4.41   3.62   0/7     77   5.58 0.038 │   -21.2   0.00       0  0.3964  8.2098 │   3.300 │  1.09   0.85
#   A2 :    20→25%   +5.4   4.46   4.00   1/7     82   9.15 0.014 │   -15.1   0.33      33  0.2423  1.5321 │   3.300 │  1.05  -2.06
#   A3 :    40→54%  +13.6   2.79   3.75   0/7     80   4.77 0.028 │   -18.9   0.00       0  0.6639  1.2967 │   1.781 │  1.04  -0.76
#   A4 :    43→49%   +6.3   2.70   3.20   0/7     79   4.50 0.012 │   -15.6   0.00       0 -0.4018  2.2357 │   1.213 │  1.02  -1.52
#   A5 :    70→83%  +13.0   1.45   0.98   3/7     79   1.33 0.017 │    -6.7   2.02     202  0.1724  1.8282 │   0.704 │  1.00  -1.88
#   A6*:    70→91%  +21.5   1.09   0.66   2/7     77   1.31 0.041 │    -1.5   0.07       7  1.2708 10.9996 │   0.223 │  0.97  -1.71
#   A7 :    90→99%   +9.1   0.55   0.27   2/7     80   0.35 0.020 │    -8.1   0.39      39  0.5440  6.7307 │   0.000 │  1.15  -1.91
#   A8 :    92→95%   +3.4   0.49   0.23   2/7     84   0.23 0.012 │    -7.0   0.22      22  0.4268  1.2324 │   0.000 │  1.28  -2.47
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1358 │ price 54→67 (peak 67)  cap=   17  TNAC=   18 │ sec= 65.4€ vol= 19.2 match=88% │ ent=0.0300  shp=1.000  eps=0.211 [ENT-DECAY] [cyc=A7]  │ warn: chron=2 bclust=1 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→21%   +1.0   5.05   4.50   0/8     72  10.24 0.011 │   -14.9   0.00       0  0.2938  7.9364 │   1.320 │  1.00  -1.30
#   A2 :    24→37%  +12.9   4.11   4.20   0/8     70   7.60 0.019 │   -17.1   0.00       0 -0.1951  7.5081 │   1.320 │  1.10  -1.08
#   A3 :    41→62%  +20.8   2.89   2.98   0/8     67   3.55 0.042 │   -21.1   0.00       0  0.0617  4.0676 │   0.027 │  0.97  -0.69
#   A4 :    42→59%  +17.1   2.62   2.95   1/8     69   3.35 0.033 │    -9.6   0.46      46  0.5724 36.0321 │   0.000 │  0.85  -3.00
#   A5 :    71→89%  +18.1   1.23   1.08   1/8     69   1.21 0.033 │   -13.7   0.41      41 -0.2205  9.1389 │   0.000 │  0.90  -1.88
#   A6 :    71→74%   +2.8   1.61   1.77   0/8     69   1.77 0.013 │   -20.7   0.00       0  0.0760  2.8233 │   0.059 │  0.96  -2.28
#   A7*:   93→100%   +7.2   0.38   0.21   0/8     63   0.32 0.035 │   -19.7   0.00       0 -0.2572 10.2660 │   0.000 │  1.01  -0.58
#   A8 :   91→100%   +8.5   0.32   0.17   7/8     69   0.19 0.030 │     3.1   1.60     160 -0.2873 31.3329 │   0.000 │  1.16  -2.10
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1455 │ price 47→96 (peak 96)  cap=   17  TNAC=   20 │ sec= 85.7€ vol= 17.4 match=75% │ ent=0.0300  shp=1.000  eps=0.208 [ENT-DECAY] [cyc=A8]  │ warn: bclust=3 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    23→31%   +7.3   4.35   4.15   0/8     73   8.13 0.016 │   -14.3   0.00       0  0.2787  1.6238 │   1.980 │  0.91  -1.52
#   A2 :    23→50%  +27.7   3.69   3.17   0/8     71   6.15 0.033 │   -21.6   0.00       0 -0.2266  3.5064 │   1.295 │  0.91  -0.44
#   A3 :    40→47%   +7.3   3.10   2.51   1/8     70   4.45 0.031 │   -10.5   1.41     141  1.0679 18.9610 │   0.926 │  0.86  -2.54
#   A4 :    41→53%  +11.8   2.99   3.31   0/8     70   4.49 0.020 │   -23.5   0.00       0  0.4048  0.9491 │   0.493 │  0.91  -2.91
#   A5 :    71→71%   +0.0   1.62   1.68   1/8     73   1.68 0.011 │   -13.2   0.75      75  0.1731  1.1954 │   0.368 │  0.86  -2.41
#   A6 :    70→82%  +11.8   1.32   1.06   0/8     73   1.30 0.011 │   -16.7   0.00       0 -0.2125  1.6470 │   0.102 │  1.01  -3.00
#   A7 :    90→91%   +0.7   0.68   0.40   0/8     69   0.52 0.039 │   -24.3   0.00       0 -0.0467 20.6991 │   0.000 │  1.05   0.02
#   A8*:   92→100%   +8.1   0.39   0.22   2/8     69   0.26 0.039 │    -9.5   0.49      49 -0.4412  9.2119 │   0.000 │  1.06  -0.58
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1552 │ price 76→66 (peak 81)  cap=   17  TNAC=   22 │ sec= 71.0€ vol= 25.7 match=100% │ ent=0.0300  shp=1.000  eps=0.206 [ENT-DECAY] [cyc=A1]  │ warn: chron=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1*:    22→39%  +17.3   3.73   3.62   0/8     82   7.16 0.035 │   -17.4   0.00       0 -0.0225  1.9390 │   5.280 │  0.96  -1.12
#   A2 :    21→21%   +0.6   4.56   4.04   4/8     92   8.33 0.005 │    -8.7   2.42     242 -0.3671  6.1836 │   5.280 │  1.19  -1.08
#   A3 :    40→54%  +13.9   2.69   3.18   0/8     85   5.05 0.025 │   -21.6   0.00       0  0.3173  3.6426 │   2.114 │  0.97  -1.48
#   A4 :    43→47%   +4.2   2.80   2.22   3/8     78   4.24 0.030 │   -11.5   1.49     149  0.2919 45.3409 │   2.678 │  0.85  -1.45
#   A5 :    71→86%  +15.2   1.37   1.80   0/8     89   1.85 0.034 │   -20.0   0.00       0  0.1317 17.2963 │   0.445 │  0.98  -0.52
#   A6 :    70→89%  +18.9   1.22   1.39   0/8     83   1.66 0.029 │   -19.8   0.00       0  0.2000  4.6183 │   0.314 │  1.07  -0.48
#   A7 :   91→100%   +8.8   0.28   0.17   3/8     80   0.22 0.055 │     3.3   0.18      18  0.3011 12.8484 │   0.000 │  1.20  -2.66
#   A8 :   91→100%   +8.9   0.42   0.29   0/8     88   0.34 0.013 │   -20.8   0.00       0 -0.0787 16.7212 │   0.000 │  0.97  -1.10
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1649 │ price 65→79 (peak 79)  cap=   17  TNAC=   25 │ sec= 74.1€ vol= 16.6 match=88% │ ent=0.0299  shp=1.000  eps=0.203 [ENT-DECAY] [cyc=A2]  │ warn: chron=2 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→24%   +4.2   4.55   2.81   6/8     75   8.08 0.011 │   -16.6  20.67    2067 -0.0232  8.3989 │   3.960 │  1.15  -0.98
#   A2*:    22→32%   +9.7   4.32   3.00   0/8     78   6.35 0.039 │   -19.5   0.00       0 -0.2840  2.1781 │   3.960 │  1.08  -0.96
#   A3 :    44→49%   +5.0   2.73   3.22   0/8     79   4.25 0.016 │   -22.8   0.00       0  0.1316  2.7272 │   1.521 │  1.01  -1.65
#   A4 :    40→57%  +16.7   2.63   3.71   0/8     81   4.30 0.033 │   -21.8   0.00       0  0.0145  0.7846 │   1.821 │  1.05  -1.17
#   A5 :    70→87%  +17.2   1.12   1.16   0/8     80   1.29 0.027 │   -19.6   0.00       0 -0.2590  0.7077 │   0.330 │  0.99  -0.93
#   A6 :    72→76%   +4.0   1.39   1.57   2/8     79   2.02 0.016 │    -6.8   1.17     117 -0.2851  4.8250 │   0.190 │  0.94  -1.88
#   A7 :   90→100%  +10.0   0.35   0.27   2/8     73   0.33 0.044 │    -9.0   0.42      42 -0.2104  4.6990 │   0.000 │  1.10  -0.27
#   A8 :   90→100%  +10.0   0.51   0.33   2/8     75   0.41 0.036 │   -12.9   1.19     119 -0.1227  3.9135 │   0.000 │  1.21  -1.91
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1746 │ price 47→89 (peak 89)  cap=   16  TNAC=   16 │ sec= 87.7€ vol= 20.5 match=100% │ ent=0.0298  shp=1.000  eps=0.200 [ENT-DECAY] [cyc=A3]  │ warn: chron=3 bclust=5
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→40%  +19.7   4.38   3.56   1/9     61   7.21 0.041 │   -12.0   0.88      88 -0.1536  5.6624 │   1.320 │  1.08  -1.56
#   A2 :    25→32%   +7.2   4.56   3.77   8/9     63   9.60 0.007 │    -7.7   5.65     565  0.0596 23.2421 │   1.320 │  1.19  -1.43
#   A3*:    40→42%   +1.7   3.30   3.90   0/9     64   6.34 0.008 │   -29.1   0.00       0  0.2002  4.5631 │   0.878 │  0.95  -0.57
#   A4 :    43→66%  +23.0   2.65   2.46   4/9     62   3.99 0.027 │    -9.4   6.52     652 -0.2385 48.7169 │   0.000 │  0.84  -2.56
#   A5 :    72→91%  +19.3   1.34   1.46   0/9     63   1.73 0.021 │   -20.4   0.00       0  0.1422  3.2081 │   0.000 │  0.89  -1.50
#   A6 :    72→86%  +13.7   1.19   1.26   0/9     61   1.55 0.033 │   -23.9   0.00       0 -0.2666  1.7589 │   0.000 │  1.00  -1.19
#   A7 :    90→95%   +4.8   0.50   0.55   1/9     66   0.55 0.008 │   -18.7   0.27      27 -0.0114  5.2779 │   0.000 │  1.13  -2.05
#   A8 :   91→100%   +8.8   0.32   0.20   0/9     64   0.21 0.033 │   -17.0   0.00       0 -0.2348  1.8614 │   0.000 │  1.22  -1.51
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1843 │ price 86→76 (peak 95)  cap=   16  TNAC=   28 │ sec= 89.5€ vol= 21.6 match=89% │ ent=0.0297  shp=1.000  eps=0.197 [ENT-DECAY] [cyc=A4]  │ warn: cov<1=1 bclust=4 hoard=2 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→28%   +8.3   4.08   3.66   0/9     89   7.44 0.019 │   -20.2   0.00       0 -0.0635  8.4431 │   5.940 │  0.92  -1.29
#   A2 :    24→29%   +4.9   4.05   3.44   2/9     96   8.63 0.004 │   -11.9   1.24     124 -0.2970 20.5632 │   5.940 │  1.18  -1.93
#   A3 :    40→51%  +11.4   2.69   3.59   0/9     95   4.86 0.012 │   -26.0   0.00       0 -0.0037  4.0480 │   2.353 │  1.01  -1.04
#   A4*:    42→43%   +1.2   2.89   3.49   0/9     93   4.36 0.018 │   -28.1   0.00       0 -0.1005  5.3149 │   3.573 │  0.89  -1.98
#   A5 :    73→95%  +22.0   0.97   0.87   0/9     92   1.23 0.037 │   -24.5   0.00       0  0.5851  9.0162 │   0.159 │  1.01   0.35
#   A6 :    72→81%   +8.5   1.29   1.47   1/9     91   1.76 0.008 │   -16.6   0.08       8 -0.0373 13.5308 │   0.252 │  0.96  -2.13
#   A7 :   90→100%  +10.0   0.29   0.12   0/9     93   0.24 0.023 │   -17.3   0.00       0  0.0491  5.9442 │   0.000 │  1.02  -0.47
#   A8 :   90→100%  +10.0   0.30   0.16   0/9     90   0.25 0.033 │   -18.3   0.00       0  0.0781  3.3145 │   0.000 │  1.07  -0.94
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  1940 │ price 57→101 (peak 101)  cap=   16  TNAC=   23 │ sec=101.3€ vol= 24.3 match=67% │ ent=0.0296  shp=1.000  eps=0.195 [ENT-DECAY] [cyc=A5]  │ warn: chron=1 bclust=4 1side=3 0vol=3
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→34%  +12.1   4.06   2.80   0/9     80   6.57 0.031 │   -22.5   0.00       0 -0.0714 42.6139 │   4.620 │  0.96  -0.58
#   A2 :    20→24%   +4.4   4.49   2.69   0/9     80   8.71 0.024 │   -21.9   0.00       0 -0.1013  5.3376 │   4.620 │  1.13   0.25
#   A3 :    43→51%   +8.1   2.65   3.69   0/9     84   4.93 0.009 │   -26.6   0.00       0 -0.0011  2.2483 │   0.979 │  0.89  -2.37
#   A4 :    41→58%  +16.1   2.77   2.68   2/9     78   4.57 0.016 │   -14.5   2.49     249 -0.1498 27.3024 │   1.504 │  0.87  -2.26
#   A5*:    70→72%   +2.3   1.54   1.96   1/9     86   2.36 0.012 │   -20.3   0.80      80 -0.1586  5.2443 │   0.615 │  0.87  -2.23
#   A6 :    70→76%   +6.1   1.42   1.85   0/9     84   2.13 0.012 │   -22.5   0.00       0 -0.1034  3.7647 │   0.041 │  0.90  -2.12
#   A7 :    90→98%   +8.3   0.48   0.23   5/9     81   0.35 0.008 │    -2.3   2.03     203 -0.2411 19.1022 │   0.000 │  1.16  -2.41
#   A8 :   93→100%   +7.0   0.42   0.29   0/9     77   0.37 0.043 │   -23.9   0.00       0 -0.1228 13.0712 │   0.000 │  1.09  -0.29
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  2037 │ price 59→100 (peak 100)  cap=   16  TNAC=   24 │ sec= 83.1€ vol= 21.7 match=89% │ ent=0.0296  shp=1.000  eps=0.192 [ENT-DECAY] [cyc=A6]  │ warn: 0inv=1 chron=1 bclust=4 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→26%   +6.5   4.72   3.10   5/9     75   9.56 0.024 │   -18.6  17.95    1795  0.1443  5.8188 │   3.300 │  1.07  -1.11
#   A2 :    21→26%   +4.7   4.55   3.49   0/9     80   7.34 0.022 │   -19.3   0.00       0  0.1673  3.9763 │   3.300 │  1.20  -1.46
#   A3 :    42→47%   +5.9   2.95   3.00   1/9     81   4.89 0.009 │   -13.4   1.51     151 -0.0192  6.3887 │   1.347 │  0.92  -1.95
#   A4 :    42→49%   +6.9   2.79   3.61   0/9     78   4.60 0.002 │   -27.2   0.00       0  0.0818  0.6304 │   0.948 │  0.97  -0.95
#   A5 :    70→74%   +4.1   1.51   2.04   1/9     77   2.15 0.004 │   -13.3   0.24      24 -0.0745 69.2305 │   0.185 │  0.92  -2.37
#   A6*:    70→83%  +12.9   1.35   1.47   0/9     77   2.02 0.019 │   -15.7   0.00       0  0.0141  1.4624 │   0.000 │  0.93  -2.07
#   A7 :   92→100%   +8.2   0.33   0.25   0/9     76   0.31 0.021 │   -12.8   0.00       0  0.0338  5.2879 │   0.000 │  0.90  -1.20
#   A8 :   92→100%   +7.8   0.44   0.15   0/9     75   0.30 0.013 │   -19.3   0.00       0  0.0172  9.3374 │   0.000 │  1.15  -1.10
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  2134 │ price 78→91 (peak 103)  cap=   16  TNAC=   26 │ sec= 89.7€ vol= 19.5 match=80% │ ent=0.0295  shp=1.000  eps=0.189 [ENT-DECAY] [cyc=A7]  │ warn: chron=2 bclust=2 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    24→40%  +16.0   3.54   3.13  0/10     94   5.72 0.013 │   -12.9   0.00       0 -0.0650  1.4915 │   6.600 │  0.88  -1.78
#   A2 :    26→30%   +4.3   3.97   3.23  2/10     91   8.08 0.029 │   -23.1   1.30     130 -0.0463  1.8996 │   6.600 │  1.12  -1.35
#   A3 :    40→46%   +5.9   2.81   3.57  0/10     96   5.17 0.011 │   -32.0   0.00       0  0.1717  0.4943 │   3.436 │  0.98  -2.42
#   A4 :    40→58%  +18.1   2.58   2.83  0/10     88   4.31 0.028 │   -23.9   0.00       0 -0.1869  2.6935 │   2.127 │  0.91  -1.69
#   A5 :    70→86%  +16.1   1.31   1.73  0/10     93   1.80 0.015 │   -23.5   0.00       0 -0.0622  1.8563 │   0.298 │  1.05  -1.92
#   A6 :    73→95%  +21.5   0.94   0.97  0/10     90   1.18 0.043 │   -29.6   0.00       0  0.0110  6.4088 │   0.101 │  1.00  -0.43
#   A7*:   90→100%  +10.0   0.31   0.14  0/10     86   0.24 0.027 │   -21.1   0.00       0  0.2793 17.5618 │   0.000 │  1.10  -0.53
#   A8 :   90→100%   +9.7   0.37   0.19  6/10     97   0.26 0.012 │    -4.1   1.88     188  0.0511  9.9331 │   0.000 │  1.29  -2.97
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  2231 │ price 58→76 (peak 76)  cap=   16  TNAC=   19 │ sec= 70.1€ vol= 21.0 match=90% │ ent=0.0294  shp=1.000  eps=0.186 [ENT-DECAY] [cyc=A8]  │ warn: chron=4 bclust=6 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→25%   +2.9   4.59   3.28  8/10     70   7.80 0.029 │   -16.4  11.43    1143  0.0317  0.9163 │   3.300 │  1.04  -0.55
#   A2 :    20→50%  +29.5   4.02   3.42  2/10     69   7.17 0.028 │   -17.9   2.70     270  0.1131  8.7478 │   2.607 │  1.14  -1.33
#   A3 :    42→50%   +7.9   2.83   3.85  0/10     73   4.81 0.013 │   -31.0   0.00       0  0.0065  4.4215 │   1.210 │  1.07  -1.21
#   A4 :    40→56%  +16.3   2.99   3.00  0/10     70   4.48 0.020 │   -16.8   0.00       0 -0.0260 33.7142 │   1.329 │  0.91  -1.78
#   A5 :    70→94%  +23.8   1.27   1.36  5/10     67   1.89 0.043 │   -10.2   3.96     396  0.2973 22.1049 │   0.204 │  0.87  -1.99
#   A6 :    70→90%  +20.0   1.03   1.03  3/10     74   1.66 0.015 │   -10.3   4.23     423  0.0092 19.1903 │   0.006 │  0.84  -2.14
#   A7 :   92→100%   +8.4   0.34   0.22  0/10     74   0.22 0.009 │   -18.4   0.00       0 -0.1082  4.4971 │   0.000 │  0.94  -1.36
#   A8*:   91→100%   +9.0   0.37   0.16  4/10     70   0.26 0.018 │    -5.4   0.69      69  0.1193  5.6181 │   0.000 │  1.10  -1.58
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  2328 │ price 74→62 (peak 85)  cap=   16  TNAC=   26 │ sec= 58.8€ vol= 20.0 match=80% │ ent=0.0293  shp=1.000  eps=0.183 [ENT-DECAY] [cyc=A1]  │ warn: chron=2 bclust=2 hoard=3 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1*:    20→50%  +29.8   3.81   2.11  3/10     68   5.63 0.039 │   -17.4   3.11     311  0.0246  7.5527 │   3.667 │  1.07  -0.51
#   A2 :    20→39%  +18.8   4.02   2.86  0/10     75   7.14 0.035 │   -28.0   0.00       0  0.0053  0.6970 │   3.960 │  1.15  -0.83
#   A3 :    46→64%  +18.4   2.39   3.22  0/10     82   3.85 0.021 │   -28.3   0.00       0  0.0171  6.8284 │   1.054 │  1.01  -1.23
#   A4 :    42→50%   +8.4   2.68   3.39  0/10     80   4.40 0.018 │   -29.1   0.00       0 -0.1422  1.8405 │   1.349 │  1.04  -1.56
#   A5 :    72→77%   +5.1   1.41   1.90  0/10     82   2.08 0.011 │   -29.2   0.00       0 -0.0139  3.7219 │   0.345 │  1.06  -1.99
#   A6 :    72→95%  +23.1   0.85   1.00  2/10     81   1.26 0.020 │    -8.2   1.14     114  0.0250 43.0732 │   0.194 │  0.96  -1.82
#   A7 :   92→100%   +7.6   0.30   0.19  2/10     82   0.20 0.011 │    -9.3   0.41      41  0.2947  0.8387 │   0.000 │  1.10  -2.03
#   A8 :    90→93%   +3.1   0.61   0.45  3/10     83   0.45 0.011 │   -17.7   1.60     160 -0.0214 24.2938 │   0.000 │  1.13  -1.13
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  2425 │ price 71→120 (peak 120)  cap=   16  TNAC=   32 │ sec=132.1€ vol= 22.8 match=80% │ ent=0.0292  shp=1.000  eps=0.181 [ENT-DECAY] [cyc=A2]  │ warn: ceil=3 chron=4 bclust=5 hoard=1 1side=2 0vol=2
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→40%  +20.2   3.81   3.16  3/10     92   6.63 0.030 │   -15.0   2.57     257 -0.0648  4.8058 │   6.574 │  0.97  -1.15
#   A2*:    23→23%   +0.0   4.38   3.01  3/10     98   9.66 0.001 │   -18.7   1.59     159  0.0763  1.4531 │   6.600 │  1.23   0.70
#   A3 :    42→47%   +4.8   2.81   3.32  0/10     96   4.55 0.027 │   -28.6   0.00       0  0.0435  3.4927 │   3.432 │  0.98  -1.85
#   A4 :    40→50%   +9.7   2.76   3.90  0/10     98   4.99 0.018 │   -30.8   0.00       0  0.0015  2.9080 │   2.970 │  1.07  -1.49
#   A5 :    70→83%  +13.2   1.19   1.55  2/10     94   1.83 0.016 │   -18.0   1.71     171 -0.0525 27.7464 │   0.408 │  0.96  -2.57
#   A6 :    72→74%   +1.6   1.44   1.76  0/10     95   2.27 0.005 │   -31.3   0.00       0  0.1169  1.5974 │   0.493 │  1.01  -0.18
#   A7 :   90→100%  +10.0   0.37   0.23  6/10     97   0.30 0.025 │     3.7   1.52     152  0.1557  9.5606 │   0.000 │  1.12  -2.40
#   A8 :   92→100%   +8.0   0.31   0.11  7/10     98   0.20 0.007 │    -1.8   2.21     221  0.1609 12.3026 │   0.000 │  1.22  -1.90
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep  2522 │ price 120→77 (peak 120)  cap=   15  TNAC=   55 │ sec= 68.9€ vol= 20.8 match=91% │ ent=0.0291  shp=1.000  eps=0.178 [ENT-DECAY] [cyc=A3]  │ warn: ceil=3 cov<1=1 chron=3 bclust=2 hoard=9 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    24→52%  +28.0   3.22   3.61  0/11    106   5.28 0.046 │   -22.5   0.00       0 -0.0107  1.2104 │   6.143 │  0.85  -2.15
#   A2 :    23→35%  +12.1   3.71   3.72  0/11    105   5.19 0.025 │   -37.0   0.00       0 -0.0199 16.6628 │   7.260 │  0.95  -0.07
# ...
#   A6 :    72→73%   +0.6   1.50   2.23  0/12    112   2.67 0.000 │   -38.7   0.00       0 1837.0133  0.7069 │   0.854 │  0.85  -2.57
#   A7 :   90→100%  +10.0   0.44   0.49  0/12    112   0.65 0.005 │   -28.7   0.00       0  0.1017  1.6780 │   0.000 │  0.80  -3.00
#   A8 :    94→95%   +1.3   0.45   0.10  4/12    111   0.21 0.001 │   -11.1   1.21     121  0.0927  7.6565 │   0.000 │  1.20  -1.83
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep 14162 │ price 73→120 (peak 120)  cap=   14  TNAC=   39 │ sec=120.0€ vol=  6.4 match=42% │ ent=0.0200  shp=1.000  eps=0.050 [ENT-DECAY] [cyc=A3]  │ warn: ceil=8 0inv=7 chron=3 bclust=9 hoard=7 1side=7 0vol=7
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→31%   +8.5   3.88   4.20  0/12    111   9.03 0.000 │   -38.7   0.00       0 -0.0562 16.7152 │   7.920 │  1.30  -3.00
#   A2 :    21→32%  +10.4   4.36   4.01  1/12    111   9.63 0.011 │   -21.9   0.20      20 2170.1085  3.6974 │   7.920 │  1.28  -2.64
#   A3*:    41→51%  +10.1   2.71   2.66  0/12    107   5.06 0.016 │   -36.4   0.00       0 149.7115  1.7858 │   3.235 │  0.87  -2.56
#   A4 :    42→45%   +2.9   2.80   3.55  0/12    111   5.93 0.000 │   -39.2   0.00       0 -0.0716  0.6009 │   4.016 │  0.80  -3.00
#   A5 :    74→74%   +0.0   1.40   1.71  1/12    109   2.43 0.001 │   -30.0   1.16     116  0.0006  5.3348 │   0.267 │  0.80  -3.00
#   A6 :    73→81%   +7.9   1.15   1.33  0/12    111   1.78 0.012 │   -34.4   0.00       0 1907.1882  1.2811 │   0.063 │  0.85  -2.36
#   A7 :    92→92%   +0.0   0.61   0.73  0/12    111   0.93 0.000 │   -34.2   0.00       0 -0.0940 24.9390 │   0.000 │  0.85  -2.33
#   A8 :    93→95%   +2.4   0.48   0.17 11/12    111   0.23 0.000 │    -6.0   5.27     527  0.0024  1.4255 │   0.000 │  1.30  -3.00
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep 14259 │ price 90→120 (peak 120)  cap=   14  TNAC=   52 │ sec=108.8€ vol= 28.9 match=75% │ ent=0.0200  shp=1.000  eps=0.050 [ENT-DECAY] [cyc=A4]  │ warn: ceil=9 0inv=3 chron=2 bclust=8 hoard=11 1side=3 0vol=3
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    21→23%   +2.7   4.39   3.97  0/12    114   9.94 0.006 │   -39.1   0.00       0  0.0357 10.5055 │   7.920 │  1.30  -3.00
#   A2 :    21→24%   +2.7   4.33   3.89  0/12    114   9.77 0.003 │   -42.7   0.00       0 -0.0743  3.0352 │   7.920 │  1.03  -1.77
#   A3 :    43→47%   +3.7   2.81   2.92  2/12    112   5.98 0.011 │   -25.0   2.10     210  1.2147 83.6446 │   4.073 │  0.82  -2.87
#   A4*:    42→58%  +15.7   2.61   3.24  0/12    112   4.78 0.010 │   -28.0   0.00       0 15.2205  9.9617 │   2.769 │  0.80  -3.00
#   A5 :    70→79%   +9.0   1.24   1.73  0/12    112   1.84 0.005 │   -43.9   0.00       0 -0.0318 36.0362 │   0.189 │  1.08   0.89
#   A6 :    76→78%   +2.1   1.27   1.93  0/12    114   2.12 0.000 │   -34.7   0.00       0 -0.0306  0.2719 │   0.000 │  0.84  -2.92
#   A7 :   92→100%   +8.4   0.46   0.60  0/12    113   0.66 0.006 │   -24.8   0.00       0 468.9271  0.7613 │   0.000 │  0.82  -2.76
#   A8 :    90→98%   +8.4   0.43   0.11  9/12    111   0.28 0.006 │    -1.2   3.24     324 -0.0328  1.2961 │   0.000 │  1.24  -2.62
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep 14356 │ price 70→120 (peak 120)  cap=   14  TNAC=   46 │ sec=120.0€ vol=  9.4 match=33% │ ent=0.0200  shp=1.000  eps=0.050 [ENT-DECAY] [cyc=A5]  │ warn: ceil=8 0inv=8 chron=2 bclust=12 hoard=7 1side=8 0vol=8
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    21→21%   +0.0   4.53   3.85  1/12    109  10.55 0.000 │   -31.6   2.66     266  0.0526  4.2154 │   7.920 │  1.29  -2.59
#   A2 :    21→32%  +11.0   4.16   2.78  5/12    108  10.11 0.008 │   -26.5  17.81    1781 186.6414 16.1252 │   7.920 │  1.23  -2.45
#   A3 :    41→43%   +1.6   2.90   3.82  0/12    109   6.25 0.006 │   -40.3   0.00       0 2611.6819  4.2758 │   4.899 │  0.86  -2.74
#   A4 :    41→46%   +4.9   2.77   3.37  1/12    109   5.85 0.007 │   -34.7   0.47      47 1781.0373  4.8463 │   3.731 │  0.82  -2.67
#   A5*:    75→83%   +8.3   1.05   1.69  0/12    109   1.71 0.000 │   -34.4   0.00       0  0.0824  2.6595 │   0.000 │  0.81  -2.73
#   A6 :    71→82%  +10.9   1.25   1.91  0/12    109   2.04 0.004 │   -33.5   0.00       0 659.8692  0.7457 │   0.129 │  0.81  -2.55
#   A7 :    91→95%   +4.0   0.50   0.67  0/12    109   0.75 0.000 │   -23.4   0.00       0 -0.0530  3.0367 │   0.000 │  0.80  -3.00
#   A8 :   91→100%   +9.4   0.37   0.15  5/12    109   0.20 0.005 │    -6.5   1.78     178 2362.5056 32.2731 │   0.000 │  1.21  -2.12
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep 14453 │ price 85→120 (peak 120)  cap=   14  TNAC=   41 │ sec=120.0€ vol=  7.4 match=33% │ ent=0.0200  shp=1.000  eps=0.050 [ENT-DECAY] [cyc=A6]  │ warn: ceil=8 0inv=5 chron=1 bclust=11 hoard=8 1side=8 0vol=8
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    21→28%   +7.5   4.36   4.60  0/12    115  10.12 0.005 │   -42.0   0.00       0  0.0494  3.8847 │   7.920 │  1.27  -2.85
#   A2 :    22→26%   +4.0   4.28   3.17  2/12    114   9.73 0.001 │   -36.0   7.06     706  0.0222  3.6352 │   7.920 │  1.30  -3.00
#   A3 :    40→48%   +7.9   2.93   3.96  0/12    113   6.30 0.007 │   -39.5   0.00       0 5336.0376  3.2701 │   5.154 │  0.83  -2.84
#   A4 :    40→56%  +15.5   2.67   3.19  0/12    113   4.94 0.011 │   -37.0   0.00       0 3510.0380  2.0382 │   2.941 │  0.80  -2.58
#   A5 :    73→76%   +3.1   1.39   1.60  0/12    114   2.31 0.009 │   -34.8   0.00       0 2009.8723  2.4031 │   0.206 │  0.80  -2.81
#   A6*:    71→85%  +14.2   1.14   1.15  0/12    111   1.80 0.010 │   -30.5   0.00       0 1350.2566  3.4103 │   0.148 │  0.82  -2.53
#   A7 :    90→95%   +5.0   0.49   0.64  0/12    114   0.73 0.007 │   -25.4   0.00       0  0.0702  2.1520 │   0.000 │  0.80  -3.00
#   A8 :    90→99%   +9.1   0.55   0.26  5/12    115   0.30 0.008 │   -14.3   2.56     256 644.1031 19.4156 │   0.000 │  1.22  -2.05
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep 14550 │ price 96→120 (peak 120)  cap=   14  TNAC=   42 │ sec=121.4€ vol= 15.5 match=92% │ ent=0.0200  shp=1.000  eps=0.050 [ENT-DECAY] [cyc=A7]  │ warn: ceil=10 0inv=2 chron=3 bclust=9 hoard=8 1side=1 0vol=1
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→24%   +4.3   4.39   3.55 11/12    115  11.73 0.001 │   -18.9  23.45    2345 700.1446  4.6654 │   7.920 │  1.27  -2.29
#   A2 :    22→29%   +7.1   4.04   4.34  0/12    116   8.84 0.004 │   -39.1   0.00       0 31.4889  3.9792 │   7.920 │  1.11  -2.14
#   A3 :    40→42%   +2.1   2.94   3.79  0/12    116   6.34 0.000 │   -35.4   0.00       0  0.0797  5.6855 │   5.211 │  0.86  -2.48
#   A4 :    42→48%   +6.1   2.72   3.32  0/12    115   5.17 0.002 │   -37.2   0.00       0  3.4692  0.5483 │   3.276 │  0.86  -2.52
#   A5 :    72→82%   +9.7   1.14   1.10  0/12    115   1.75 0.007 │   -23.7   0.00       0 1171.7230 31.8552 │   0.161 │  0.82  -2.80
#   A6 :    70→77%   +7.4   1.31   1.80  0/12    116   2.12 0.001 │   -35.1   0.00       0 1037.5226  0.5982 │   0.220 │  0.84  -2.55
#   A7*:    91→94%   +3.3   0.51   0.61  0/12    116   0.77 0.000 │   -32.9   0.00       0  0.0708  2.5561 │   0.000 │  0.80  -3.00
#   A8 :   91→100%   +9.2   0.32   0.11  0/12    110   0.28 0.050 │   -27.5   0.00       0 -0.0892 20.6702 │   0.000 │  1.03  -0.36
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep 14647 │ price 100→120 (peak 120)  cap=   14  TNAC=   56 │ sec=120.0€ vol=  4.7 match=17% │ ent=0.0200  shp=1.000  eps=0.050 [ENT-DECAY] [cyc=A8]  │ warn: ceil=11 0inv=6 chron=3 bclust=12 hoard=10 1side=10 0vol=10
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    20→31%  +11.2   4.03   3.47  0/12    118   8.54 0.005 │   -33.8   0.00       0 263.6516  3.7978 │   7.920 │  1.29  -2.59
#   A2 :    22→29%   +7.6   3.97   4.16  0/12    118   9.22 0.000 │   -41.6   0.00       0 -0.0772 16.0772 │   7.920 │  1.09  -2.12
#   A3 :    44→60%  +15.7   2.52   3.51  0/12    118   4.80 0.008 │   -37.5   0.00       0 633.4986  0.8019 │   1.912 │  0.80  -2.80
#   A4 :    42→47%   +4.7   2.76   3.50  0/12    118   5.57 0.003 │   -40.5   0.00       0 532.2429  1.2993 │   3.641 │  0.81  -2.87
#   A5 :    75→76%   +1.7   1.33   1.60  0/12    118   2.24 0.000 │   -34.8   0.00       0 -0.0284  0.5491 │   0.032 │  0.81  -2.84
#   A6 :    71→81%  +10.6   1.31   1.65  0/12    117   2.08 0.010 │   -32.4   0.00       0 978.7633  1.2350 │   0.147 │  0.84  -2.73
#   A7 :    92→94%   +1.8   0.51   0.58  0/12    118   0.77 0.000 │   -29.8   0.00       0 -0.0410  1.1482 │   0.000 │  0.80  -3.00
#   A8*:   92→100%   +7.7   0.31   0.12 11/12    118   0.19 0.014 │     4.2   2.81     281  0.3165 20.8806 │   0.000 │  1.30  -3.00
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep 14744 │ price 80→120 (peak 120)  cap=   14  TNAC=   54 │ sec=120.0€ vol=  7.2 match=25% │ ent=0.0200  shp=1.000  eps=0.050 [ENT-DECAY] [cyc=A1]  │ warn: ceil=10 0inv=2 chron=2 bclust=11 hoard=9 1side=9 0vol=9
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1*:    22→31%   +9.2   3.84   4.43  0/12    115   8.68 0.000 │   -41.2   0.00       0 -0.0983 13.6664 │   7.920 │  1.09  -1.42
#   A2 :    26→30%   +4.3   3.86   3.32  0/12    114   8.14 0.003 │   -27.5   0.00       0 1019.8373  4.8425 │   7.920 │  1.30  -3.00
#   A3 :    44→51%   +7.5   2.62   3.74  0/12    115   5.02 0.003 │   -40.6   0.00       0  0.0499  1.2067 │   2.419 │  0.89  -2.24
#   A4 :    40→43%   +3.3   2.91   3.40  0/12    115   6.25 0.001 │   -40.2   0.00       0  0.0348  0.9425 │   4.948 │  0.84  -2.46
#   A5 :    73→86%  +13.1   1.10   1.29  0/12    114   1.54 0.009 │   -30.5   0.00       0 2153.4246  6.8238 │   0.108 │  0.90  -2.68
#   A6 :    71→82%  +10.9   1.19   1.26  1/12    114   1.64 0.009 │   -25.6   0.39      39 737.7132 13.3053 │   0.268 │  0.80  -3.00
#   A7 :   90→100%  +10.0   0.42   0.47  0/12    115   0.55 0.020 │   -28.5   0.00       0 3762.5044  2.6719 │   0.000 │  0.80  -3.00
#   A8 :   91→100%   +9.1   0.42   0.22  8/12    114   0.25 0.019 │    -4.1   2.91     291 2244.0747  2.1868 │   0.000 │  1.27  -2.90
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep 14841 │ price 56→113 (peak 120)  cap=   14  TNAC=   47 │ sec=107.1€ vol=  7.5 match=42% │ ent=0.0200  shp=1.000  eps=0.050 [ENT-DECAY] [cyc=A2]  │ warn: ceil=8 0inv=4 chron=1 bclust=9 hoard=7 1side=7 0vol=7
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    22→39%  +17.6   3.62   3.34  0/12    108   7.65 0.009 │   -30.8   0.00       0  0.1365  8.6948 │   7.260 │  1.30  -2.77
#   A2*:    23→33%  +10.3   4.19   3.42  6/12    107   9.29 0.011 │   -19.6  11.09    1109  0.2581  6.3922 │   7.260 │  1.22  -2.31
#   A3 :    42→46%   +3.9   2.82   3.67  0/12    108   5.85 0.000 │   -34.2   0.00       0 -0.0038 16.4075 │   3.351 │  0.80  -3.00
#   A4 :    43→67%  +24.0   2.68   3.71  0/12    107   4.53 0.018 │   -38.3   0.00       0 1541.6383  3.5563 │   2.739 │  0.88  -2.43
#   A5 :    70→72%   +2.3   1.53   2.07  0/12    103   2.75 0.000 │   -38.6   0.00       0 -0.0625  1.5223 │   0.994 │  0.91  -2.66
#   A6 :    73→87%  +14.3   1.02   1.10  2/12    106   1.70 0.007 │   -22.8   0.47      47 403.8712  7.3797 │   0.023 │  0.81  -2.71
#   A7 :   92→100%   +8.1   0.43   0.53  0/12    108   0.65 0.005 │   -25.8   0.00       0 1113.8913  0.4563 │   0.000 │  0.81  -2.97
#   A8 :   91→100%   +9.0   0.31   0.05  2/12    105   0.17 0.012 │   -16.2   0.55      55  0.0144 12.6510 │   0.000 │  1.22  -2.42
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Ep 14938 │ price 81→101 (peak 120)  cap=   14  TNAC=   57 │ sec= 87.2€ vol= 14.0 match=58% │ ent=0.0200  shp=1.000  eps=0.050 [ENT-DECAY] [cyc=A3]  │ warn: ceil=8 0inv=5 chron=2 bclust=9 hoard=8 1side=5 0vol=5
#               Grn     ΔG  Emiss  Alloc    Sf   Bid€  BidMt InvFr │     Rew  Short     Pen   ALoss   CLoss │  MAC_Mt │ SecMl  SqAct
#   A1 :    21→34%  +13.2   3.85   3.10  2/12    113   7.98 0.007 │   -20.2   1.26     126 1758.2902 24.4425 │   7.920 │  1.27  -2.70
#   A2 :    22→44%  +22.4   3.49   2.88  5/12    109   7.94 0.021 │   -21.6  11.13    1113 2696.5192 12.3683 │   7.079 │  1.27  -2.18
#   A3*:    42→48%   +5.7   2.71   4.34  0/12    114   5.52 0.003 │   -40.3   0.00       0 1892.6734  0.9279 │   3.205 │  0.85  -2.25
#   A4 :    42→45%   +3.4   2.81   4.24  0/12    114   5.85 0.001 │   -40.9   0.00       0  0.1196  1.5161 │   4.218 │  0.87  -2.68
#   A5 :    70→88%  +18.4   0.93   1.25  0/12    112   1.42 0.011 │   -34.6   0.00       0 97.3115  2.4568 │   0.165 │  0.86  -2.34
#   A6 :    70→74%   +4.3   1.44   1.93  0/12    114   2.24 0.000 │   -34.9   0.00       0  0.0509  7.5691 │   0.586 │  0.82  -2.51
#   A7 :   90→100%   +9.9   0.37   0.35  0/12    112   0.50 0.012 │   -18.1   0.00       0  0.1375 26.2360 │   0.000 │  0.87  -2.63
#   A8 :    91→95%   +3.6   0.49   0.16  6/12    114   0.20 0.000 │   -12.7   2.33     233 539.3287 26.0591 │   0.000 │  1.28  -2.62
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Done — seed 42. Logs: results/training_log_s42.csv, results/year_log_s42.csv

# %%
from google.colab import files
files.download('results/training_log_s42.csv')
files.download('results/year_log_s42.csv')
